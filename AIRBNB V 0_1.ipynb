# %% [markdown]
# # Analyze AirBnB Data for Seattle and Boston

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
from matplotlib import style
style.use('ggplot')
from zipfile import ZipFile
import requests

# %%
# Change default settings to allow seeing all of the data in a table.
pd.options.display.max_columns = 100
pd.options.display.max_rows = 40
pd.set_option('display.max_colwidth', 20)

# Supress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Business Understanding

# %% [markdown]
# So you want to start earning income by putting your home on AirBnB.  What are the most important things to know?
# Three questions:
#
# 1) What locations in Seattle and Boston are the most popular (have the most rentals)?
# 2) Is there a difference in the median rental income for Seattle and Boston?
# 3) What features are correlated with higher rental income?
# 4) Does the rental income vary over time?

# %% [markdown]
# ### Data Understanding
#
# The following files are found in the AirBnB data for Boston and Seattle:
#
# Boston:
# calendar.csv, listings.csv, reviews.csv
#
# Seattle:
# calendar.csv, listings.csv, reviews.csv
#
# They were downloaded from the AirBnB site at the follwing url:  http://insideairbnb.com/get-the-data.html
#
# I changed the name of each file by adding a "-Boston" or "-Seattle" to identify the specific data.

# %%
city_names = ['Boston', 'Seattle']

location_names = ['boston', 'seattle']

file_names = ['airbnb_seattle_listings.csv.gz',
              'airbnb_seattle_calendar.csv.gz',
              'airbnb_seattle_reviews.csv.gz',
              'airbnb_boston_listings.csv.gz',
              'airbnb_boston_calendar.csv.gz',
              'airbnb_boston_reviews.csv.gz']

destination_file_names = ['airbnb_seattle_listings.csv',
              'airbnb_seattle_calendar.csv',
              'airbnb_seattle_reviews.csv',
              'airbnb_boston_listings.csv',
              'airbnb_boston_calendar.csv',
              'airbnb_boston_reviews.csv']

destination_file = ['airbnb_seattle_listings',
              'airbnb_seattle_calendar',
              'airbnb_seattle_reviews',
              'airbnb_boston_listings',
              'airbnb_boston_calendar',
              'airbnb_boston_reviews']

abbr_list = ['listings.csv', 'calendar.csv', 'reviews.csv']

# file names for boston on http://insideairbnb.com/get-the-data.html website:
citydata = ['http://data.insideairbnb.com/united-states/wa/seattle/2020-10-25/data/listings.csv.gz',
'http://data.insideairbnb.com/united-states/wa/seattle/2020-10-25/data/calendar.csv.gz',
'http://data.insideairbnb.com/united-states/wa/seattle/2020-10-25/data/reviews.csv.gz',
'http://data.insideairbnb.com/united-states/ma/boston/2020-11-10/data/listings.csv.gz',
'http://data.insideairbnb.com/united-states/ma/boston/2020-11-10/data/calendar.csv.gz',
'http://data.insideairbnb.com/united-states/ma/boston/2020-11-10/data/reviews.csv.gz']

# %%
# This code takes the file names and city data above and loads the zip files onto your local directory
for i in range(6):

    url = citydata[i]

    filename = file_names[i]

    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

# %%
for i in range(6):
    destination_file[i] = pd.read_csv(file_names[i], compression = 'infer')

# %%
    
airbnb_seattle_listings = destination_file[0]
airbnb_seattle_calendar = destination_file[1]
airbnb_seattle_reviews = destination_file[2]
airbnb_boston_listings = destination_file[3]
airbnb_boston_calendar = destination_file[4]
airbnb_boston_reviews = destination_file[5]

# %%
'''This code reads the comma separated data downloade from the AirBnB website

    The data was provided by Udacity in support of the Data Science Nanodegree.'''

# Read in Seattle Data
airbnb_seattle_calendar = pd.read_csv('calendar-Seattle.csv')
airbnb_seattle_listings = pd.read_csv('listings-Seattle.csv')
airbnb_seattle_reviews = pd.read_csv('reviews-Seattle.csv')

# Read in Boston Data
airbnb_boston_calendar = pd.read_csv('calendar-Boston.csv')
airbnb_boston_listings = pd.read_csv('listings-Boston.csv')
airbnb_boston_reviews = pd.read_csv('reviews-Boston.csv')

# %%
airbnb_seattle_calendar['city'] = 'Seattle'
airbnb_seattle_listings['city'] = 'Seattle'
airbnb_seattle_reviews['city'] = 'Seattle'
airbnb_boston_calendar['city'] = 'Boston'
airbnb_boston_listings['city'] = 'Boston'
airbnb_boston_reviews['city'] = 'Boston'

# %%
print(airbnb_seattle_calendar.shape, airbnb_boston_calendar.shape)
print(airbnb_seattle_listings.shape, airbnb_boston_listings.shape)
print(airbnb_seattle_reviews.shape, airbnb_boston_reviews.shape)
# Out:
# (1582275, 8) (1180775, 8)
# (4335, 75) (3236, 75)
# (270875, 7) (123710, 7)

# %% [markdown]
# Based on the shape of each dataset, we should be able to concatenate boston and seattle under the same datasets, reducing the 6 files to 3.

# %%
frames_calendar = [airbnb_seattle_calendar,airbnb_boston_calendar ]
frames_listings = [airbnb_seattle_listings, airbnb_boston_listings]
reviews_listings =[airbnb_seattle_reviews, airbnb_boston_reviews]

calendar = pd.concat(frames_calendar)
listings = pd.concat(frames_listings)
reviews = pd.concat(reviews_listings)

# %%
print(calendar.shape)
print(listings.shape)
print(reviews.shape)
# Out:
# (2763050, 8)
# (7571, 75)
# (394585, 7)

# %% [markdown]
# Isuses with calendar data:
# 1) need to ensure data is datetime format
#
# 2) available column should be True or False (boolean)
#
# 3) remove the "$" symbol from the price column and convert it to a float64.
#
# 4)

# %% [markdown]
# Let's begin by looking at the Seattle data files.

# %%
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0    22153582  2020-10-25         t  $144.00        $144.00               3
# 1    22153582  2020-10-26         t  $141.00        $141.00               3
# 2    22153582  2020-10-27         t  $149.00        $149.00               3
# 3    22153582  2020-10-28         t   $96.00         $96.00               3
# 4    22153582  2020-10-29         t  $102.00        $102.00               3
#
#    maximum_nights     city
# 0            1125  Seattle
# 1            1125  Seattle
# 2            1125  Seattle
# 3            1125  Seattle
# 4            1125  Seattle

# %% [markdown]
# Notice that the price, weekly_price, monthly_prie, security_deposit, cleaning_fee, extra-people columns include the $ sign.  This will cause these variables to appear objects.  This will need to be removed and converted to  float64.

# %%
listings.head()
# Out:
#      id          listing_url       scrape_id last_scraped  \
# 0  2318  https://www.airb...  20201025051148   2020-10-25
# 1  9419  https://www.airb...  20201025051148   2020-10-25
# 2  9531  https://www.airb...  20201025051148   2020-10-25
# 3  9534  https://www.airb...  20201025051148   2020-10-25
# 4  9596  https://www.airb...  20201025051148   2020-10-25
#
#                   name          description neighborhood_overview  \
# 0  Casa Madrona - U...  Gorgeous, archit...  Madrona is a hid...
# 1  Glorious sun roo...  Keeping you safe...  Lots of restaura...
# 2  The Adorable Swe...  The Sweet Orange...  The neighborhood...
# 3  The Coolest Tang...  Welcome to my de...  The neighborhood...
# 4  the down home , ...  We are in a grea...  if you arrive ea...
#
#            picture_url  host_id             host_url  host_name  host_since  \
# 0  https://a0.musca...     2536  https://www.airb...      Megan  2008-08-26
# 1  https://a0.musca...    30559  https://www.airb...  Angielena  2009-08-09
# 2  https://a0.musca...    31481  https://www.airb...     Cassie  2009-08-13
# 3  https://a0.musca...    31481  https://www.airb...     Cassie  2009-08-13
# 4  https://a0.musca...    14942  https://www.airb...      Joyce  2009-04-26
#
#          host_location           host_about  host_response_time  \
# 0  Seattle, Washing...  I welcome guests...        within a day
# 1  Seattle, Washing...  I am a visual ar...  within a few hours
# 2  Seattle, Washing...  The Sweet Orange...        within a day
# 3  Seattle, Washing...  The Sweet Orange...        within a day
# 4  Seattle, Washing...  I am a therapist...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  78%                 t
# 1               100%                  89%                 t
# 2               100%                  64%                 t
# 3               100%                  64%                 t
# 4                90%                  94%                 f
#
#     host_thumbnail_url     host_picture_url host_neighbourhood  \
# 0  https://a0.musca...  https://a0.musca...              Minor
# 1  https://a0.musca...  https://a0.musca...         Georgetown
# 2  https://a0.musca...  https://a0.musca...       The Junction
# 3  https://a0.musca...  https://a0.musca...       The Junction
# 4  https://a0.musca...  https://a0.musca...        Wallingford
#
#    host_listings_count  host_total_listings_count   host_verifications  \
# 0                  2.0                  2.0        ['email', 'phone...
# 1                  8.0                  8.0        ['email', 'phone...
# 2                  2.0                  2.0        ['email', 'phone...
# 3                  2.0                  2.0        ['email', 'phone...
# 4                  5.0                  5.0        ['email', 'phone...
#
#   host_has_profile_pic host_identity_verified        neighbourhood  \
# 0                    t                    t    Seattle, Washing...
# 1                    t                    t    Seattle, Washing...
# 2                    t                    t    Seattle, Washing...
# 3                    t                    t    Seattle, Washing...
# 4                    t                    t    Seattle, Washing...
#
#   neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 0              Madrona           Central Area          47.61082 -122.29082
# 1           Georgetown    Other neighborhoods          47.55017 -122.31937
# 2       Fairmount Park           West Seattle          47.55539 -122.38474
# 3       Fairmount Park           West Seattle          47.55624 -122.38598
# 4          Wallingford    Other neighborhoods          47.65479 -122.33652
#
#          property_type        room_type  accommodates  bathrooms  \
# 0         Entire house  Entire home/apt             9        NaN
# 1  Private room in ...     Private room             2        NaN
# 2         Entire house  Entire home/apt             4        NaN
# 3   Entire guest suite  Entire home/apt             3        NaN
# 4     Entire apartment  Entire home/apt             4        NaN
#
#    bathrooms_text  bedrooms  beds            amenities    price  \
# 0       2.5 baths       4.0   4.0  ["Children\u2019...  $295.00
# 1  3 shared baths       1.0   2.0  ["Iron", "Hanger...   $55.00
# 2          1 bath       2.0   3.0  ["Iron", "TV", "...  $155.00
# 3          1 bath       2.0   2.0  ["Conditioner", ...  $125.00
# 4          1 bath       1.0   4.0  ["Iron", "TV", "...  $100.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               1            1125                  1.0
# 1               2             180                  2.0
# 2              28            1125                 28.0
# 3               5            1125                  5.0
# 4               4              60                  4.0
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                  2.0                  1125.0                  1125.0
# 1                  2.0                   180.0                   180.0
# 2                 28.0                  1125.0                  1125.0
# 3                  5.0                  1125.0                  1125.0
# 4                  4.0                  1125.0                  1125.0
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                  1.0                  1125.0                  NaN
# 1                  2.0                   180.0                  NaN
# 2                 28.0                  1125.0                  NaN
# 3                  5.0                  1125.0                  NaN
# 4                  4.0                  1125.0                  NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0               26
# 1                t               29               59               89
# 2                t                0                0               19
# 3                t               10               14               40
# 4                t                0                0                6
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                26           2020-10-25                  32
# 1               364           2020-10-25                 148
# 2               294           2020-10-25                  40
# 3               315           2020-10-25                  53
# 4                 6           2020-10-25                  97
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                    4                      0      2008-09-15  2020-02-01
# 1                    2                      0      2010-07-30  2019-12-27
# 2                    1                      0      2012-01-12  2019-12-30
# 3                    8                      0      2012-01-15  2020-08-31
# 4                    4                      1      2011-06-15  2020-09-28
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                100.0                  10.0                    10.0
# 1                 93.0                  10.0                    10.0
# 2                100.0                  10.0                    10.0
# 3                100.0                  10.0                    10.0
# 4                 91.0                   9.0                     9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                 10.0                   10.0                         10.0
# 1                 10.0                   10.0                         10.0
# 2                 10.0                   10.0                         10.0
# 3                 10.0                   10.0                         10.0
# 4                 10.0                    9.0                         10.0
#
#    review_scores_value             license instant_bookable  \
# 0                 10.0  STR-OPLI-19-002837                f
# 1                 10.0  str-opli-19-003039                f
# 2                 10.0  STR-OPLI-19-002182                f
# 3                 10.0  STR-OPLI-19-002182                f
# 4                  9.0  STR-OPLI-19-002622                f
#
#    calculated_host_listings_count  \
# 0                    2
# 1                    8
# 2                    2
# 3                    2
# 4                    2
#
#    calculated_host_listings_count_entire_homes  \
# 0                    2
# 1                    0
# 2                    2
# 3                    2
# 4                    2
#
#    calculated_host_listings_count_private_rooms  \
# 0                    0
# 1                    8
# 2                    0
# 3                    0
# 4                    0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month     city
# 0                    0                                       0.22  Seattle
# 1                    0                                       1.19  Seattle
# 2                    0                                       0.37  Seattle
# 3                    0                                       0.50  Seattle
# 4                    0                                       0.85  Seattle

# %%
 (listings.bathrooms.notnull().sum())
# Out:
# 0

# %%
listings.bathrooms_text.value_counts()
# Out:
# 1 bath               4426
# 1 shared bath         832
# 2 baths               800
# 1 private bath        400
# 1.5 baths             250
# 2 shared baths        243
# 2.5 baths             183
# 1.5 shared baths      139
# 3 baths                93
# 3.5 baths              71
# 3 shared baths         41
# 2.5 shared baths       22
# 0 shared baths         13
# 4 baths                11
# Half-bath               7
# 4.5 baths               6
# 0 baths                 5
# 3.5 shared baths        4
# 6 baths                 3
# 5 shared baths          3
# 6 shared baths          3
# 4 shared baths          3
# Shared half-bath        2
# Private half-bath       2
# 11 baths                1
# 5 baths                 1
# Name: bathrooms_text, dtype: int64

# %%
listings['bathrooms'].value_counts()
# Out:
# 1.0     5658
# 2.0     1043
# 1.5      389
# 2.5      205
# 3.0      134
# 3.5       75
# 0.0       18
# 4.0       14
# 0.5       11
# 6.0        6
# 4.5        6
# 5.0        4
# 11.0       1
# Name: bathrooms, dtype: int64

# %%
amenit= listings.amenities.value_counts()
print(amenit)
# Out:
# ["Iron", "TV", "Hangers", "Private entrance", "Hair dryer", "Carbon monoxide alarm", "Microwave", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Refrigerator", "Kitchen", "Washer", "Dishes and silverware", "Stove", "Coffee maker", "Cooking basics", "BBQ grill", "Shampoo", "Laptop-friendly workspace", "Bed linens", "Oven", "Hot water", "Gym", "Dryer", "Long term stays allowed", "Essentials"]                                                                                                               47
# ["Washer", "Kitchen", "Hair dryer", "Laptop-friendly workspace", "Gym", "Elevator", "Dishes and silverware", "Long term stays allowed", "Wifi", "Bed linens", "Refrigerator", "Extra pillows and blankets", "Smoke alarm", "Microwave", "BBQ grill", "Stove", "Coffee maker", "Essentials", "Oven", "Hangers", "Pool", "Cooking basics", "Private entrance", "TV", "Carbon monoxide alarm", "Iron", "Dryer"]                                                                                                                   46
# ["Iron", "TV", "Hangers", "Private entrance", "Hair dryer", "Carbon monoxide alarm", "Air conditioning", "Microwave", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Refrigerator", "Kitchen", "Washer", "Dishes and silverware", "Stove", "Coffee maker", "Cooking basics", "BBQ grill", "Shampoo", "Laptop-friendly workspace", "Bed linens", "Oven", "Hot water", "Gym", "Dryer", "Long term stays allowed", "Patio or balcony", "Essentials"]                                                                       35
# ["Wifi", "Shampoo", "Gym", "Smoke alarm", "Fire extinguisher", "Dryer", "Laptop-friendly workspace", "Iron", "TV", "Kitchen", "Hangers", "Heating", "Washer", "Essentials", "Hair dryer", "Carbon monoxide alarm", "Elevator", "Air conditioning", "First aid kit"]                                                                                                                                                                                                                                                            34
# ["Wifi", "Shampoo", "Gym", "Fire extinguisher", "Smoke alarm", "Dryer", "Laptop-friendly workspace", "Iron", "TV", "Kitchen", "Hangers", "Heating", "Washer", "Essentials", "Hair dryer", "Carbon monoxide alarm", "Elevator", "Air conditioning", "First aid kit"]                                                                                                                                                                                                                                                            33
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ..
# ["Luggage dropoff allowed", "Washer", "Kitchen", "Keypad", "Hair dryer", "Laptop-friendly workspace", "Dishes and silverware", "Long term stays allowed", "Wifi", "Air conditioning", "Refrigerator", "Smoke alarm", "Microwave", "Stove", "Coffee maker", "Oven", "Dishwasher", "Hot water", "Heating", "Carbon monoxide alarm", "Dryer"]                                                                                                                                                                                      1
# ["Free street parking", "Hot water", "Wifi", "Shampoo", "Smoke alarm", "Refrigerator", "Laptop-friendly workspace", "Hangers", "Heating", "Private entrance", "Essentials", "Hair dryer", "Free parking on premises", "First aid kit"]                                                                                                                                                                                                                                                                                          1
# ["Free street parking", "Wifi", "Fire extinguisher", "Smoke alarm", "Dryer", "Laptop-friendly workspace", "Iron", "TV", "Kitchen", "Hangers", "Heating", "Private entrance", "Washer", "Essentials", "Lockbox", "Free parking on premises", "Carbon monoxide alarm", "Coffee maker", "Microwave"]                                                                                                                                                                                                                               1
# ["Iron", "TV", "Hangers", "Cable TV", "Private entrance", "Hair dryer", "Microwave", "Dishwasher", "Wifi", "Smoke alarm", "Refrigerator", "Kitchen", "Indoor fireplace", "Washer", "Dishes and silverware", "Stove", "Coffee maker", "Cooking basics", "Shampoo", "Laptop-friendly workspace", "Free parking on premises", "Oven", "Fire extinguisher", "Dryer", "Heating", "Essentials"]                                                                                                                                       1
# ["Luggage dropoff allowed", "Washer", "Kitchen", "Hair dryer", "Window guards", "Shower gel", "Gym", "Dishes and silverware", "Long term stays allowed", "Wifi", "Bed linens", "Air conditioning", "Refrigerator", "Extra pillows and blankets", "Microwave", "Fire extinguisher", "Baking sheet", "Stove", "Coffee maker", "Shampoo", "Oven", "Cable TV", "Hangers", "Dryer", "Pool", "Hot water", "Paid parking off premises", "Cooking basics", "Dishwasher", "TV", "Ethernet connection", "Heating", "Iron", "Bathtub"]     1
# Name: amenities, Length: 6228, dtype: int64

# %%
phrase_dict = {}

for phrase in listings.amenities[1]:
    print(phrase)
# Out:
# ["Iron", "Hangers", "Lock on bedroom door", "Hair dryer", "Carbon monoxide alarm", "Air conditioning", "Microwave", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Refrigerator", "Kitchen", "Washer", "Private living room", "Dishes and silverware", "Stove", "Coffee maker", "Free street parking", "Cooking basics", "Shampoo", "Host greets you", "Laptop-friendly workspace", "Bed linens", "Free parking on premises", "Oven", "First aid kit", "Hot water", "Fire extinguisher", "Dryer", "Long term stays allowed", "Patio or balcony", "Heating", "Essentials"]
# ["Luggage dropoff allowed", "Washer", "Keypad", "Hair dryer", "Laptop-friendly workspace", "Dishes and silverware", "Long term stays allowed", "Wifi", "Bed linens", "Air conditioning", "Refrigerator", "Extra pillows and blankets", "Smoke alarm", "Microwave", "Fire extinguisher", "First aid kit", "Coffee maker", "Free street parking", "Shampoo", "Essentials", "Cable TV", "Hangers", "Dryer", "Hot water", "Private entrance", "TV", "Heating", "Carbon monoxide alarm", "Iron", "Bathtub"]

# %% [markdown]
# Need to change the following columns from "t" or "f" to "True" or "False" and make boolean:
# host_is_superhost, host_has_profile_pic, host_identity_verified, is_location_exact, has_availability, requires_license,
# instant_bookable, require_guest_profile_pic, require_guest_phone_verification.
#
# name, summary, space, description, neighborhood_overview, notes, transit, street, amenities, zipcode, scrape_id, and last_scraped are not needed for our analysis.  They will be dropped.

# %%
listings.room_type.value_counts()
# Out:
# Entire home/apt    5566
# Private room       1925
# Hotel room           42
# Shared room          38
# Name: room_type, dtype: int64

# %%
listings['host_is_superhost'].value_counts()
# Out:
# f    4313
# t    3250
# Name: host_is_superhost, dtype: int64

# %%
# identify columns with numeric values
num_columns = listings.select_dtypes(include = ['int64', 'float64']).columns
num_columns
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
#        'number_of_reviews_l30d', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7571 entries, 0 to 3235
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7571 non-null   int64
#  1   listing_url                                   7571 non-null   object
#  2   scrape_id                                     7571 non-null   int64
#  3   last_scraped                                  7571 non-null   object
#  4   name                                          7571 non-null   object
#  5   description                                   7532 non-null   object
#  6   neighborhood_overview                         5340 non-null   object
#  7   picture_url                                   7571 non-null   object
#  8   host_id                                       7571 non-null   int64
#  9   host_url                                      7571 non-null   object
#  10  host_name                                     7563 non-null   object
#  11  host_since                                    7563 non-null   object
#  12  host_location                                 7553 non-null   object
#  13  host_about                                    5259 non-null   object
#  14  host_response_time                            6303 non-null   object
#  15  host_response_rate                            6303 non-null   object
#  16  host_acceptance_rate                          6723 non-null   object
#  17  host_is_superhost                             7563 non-null   object
#  18  host_thumbnail_url                            7563 non-null   object
#  19  host_picture_url                              7563 non-null   object
#  20  host_neighbourhood                            6962 non-null   object
#  21  host_listings_count                           7563 non-null   float64
#  22  host_total_listings_count                     7563 non-null   float64
#  23  host_verifications                            7571 non-null   object
#  24  host_has_profile_pic                          7563 non-null   object
#  25  host_identity_verified                        7563 non-null   object
#  26  neighbourhood                                 5340 non-null   object
#  27  neighbourhood_cleansed                        7571 non-null   object
#  28  neighbourhood_group_cleansed                  4335 non-null   object
#  29  latitude                                      7571 non-null   float64
#  30  longitude                                     7571 non-null   float64
#  31  property_type                                 7571 non-null   object
#  32  room_type                                     7571 non-null   object
#  33  accommodates                                  7571 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                7564 non-null   object
#  36  bedrooms                                      6606 non-null   float64
#  37  beds                                          7518 non-null   float64
#  38  amenities                                     7571 non-null   object
#  39  price                                         7571 non-null   object
#  40  minimum_nights                                7571 non-null   int64
#  41  maximum_nights                                7571 non-null   int64
#  42  minimum_minimum_nights                        7570 non-null   float64
#  43  maximum_minimum_nights                        7570 non-null   float64
#  44  minimum_maximum_nights                        7570 non-null   float64
#  45  maximum_maximum_nights                        7570 non-null   float64
#  46  minimum_nights_avg_ntm                        7570 non-null   float64
#  47  maximum_nights_avg_ntm                        7570 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              7571 non-null   object
#  50  availability_30                               7571 non-null   int64
#  51  availability_60                               7571 non-null   int64
#  52  availability_90                               7571 non-null   int64
#  53  availability_365                              7571 non-null   int64
#  54  calendar_last_scraped                         7571 non-null   object
#  55  number_of_reviews                             7571 non-null   int64
#  56  number_of_reviews_ltm                         7571 non-null   int64
#  57  number_of_reviews_l30d                        7571 non-null   int64
#  58  first_review                                  5874 non-null   object
#  59  last_review                                   5874 non-null   object
#  60  review_scores_rating                          5842 non-null   float64
#  61  review_scores_accuracy                        5807 non-null   float64
#  62  review_scores_cleanliness                     5808 non-null   float64
#  63  review_scores_checkin                         5806 non-null   float64
#  64  review_scores_communication                   5809 non-null   float64
#  65  review_scores_location                        5807 non-null   float64
#  66  review_scores_value                           5807 non-null   float64
#  67  license                                       4828 non-null   object
#  68  instant_bookable                              7571 non-null   object
#  69  calculated_host_listings_count                7571 non-null   int64
#  70  calculated_host_listings_count_entire_homes   7571 non-null   int64
#  71  calculated_host_listings_count_private_rooms  7571 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   7571 non-null   int64
#  73  reviews_per_month                             5874 non-null   float64
#  74  city                                          7571 non-null   object
# dtypes: float64(22), int64(17), object(36)
# memory usage: 4.4+ MB

# %%
reviews.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0        2318        146  2008-09-15         2451         Kevin
# 1        2318  126302712  2017-01-10     12332845       Jessica
# 2        2318  140977084  2017-04-01      4789466          Ivan
# 3        2318  147262504  2017-04-25     55817131          Mike
# 4        2318  161806368  2017-06-18    113604590          Pete
#
#               comments     city
# 0  1000 times bette...  Seattle
# 1  Our family (two ...  Seattle
# 2  Top of the list ...  Seattle
# 3  SUCH an awesome ...  Seattle
# 4  We flew quite a ...  Seattle

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2763050 entries, 0 to 1180774
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
#  7   city            object
# dtypes: int64(3), object(5)
# memory usage: 189.7+ MB

# %% [markdown]
# This confirms what we observed earlier.  The price column is identified as an object.  It should be float64.  Also, the date is not a datetime.  We will need to convert this as well.  We can also consider making datetime as an index to allow for time series analysis.

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7571 entries, 0 to 3235
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7571 non-null   int64
#  1   listing_url                                   7571 non-null   object
#  2   scrape_id                                     7571 non-null   int64
#  3   last_scraped                                  7571 non-null   object
#  4   name                                          7571 non-null   object
#  5   description                                   7532 non-null   object
#  6   neighborhood_overview                         5340 non-null   object
#  7   picture_url                                   7571 non-null   object
#  8   host_id                                       7571 non-null   int64
#  9   host_url                                      7571 non-null   object
#  10  host_name                                     7563 non-null   object
#  11  host_since                                    7563 non-null   object
#  12  host_location                                 7553 non-null   object
#  13  host_about                                    5259 non-null   object
#  14  host_response_time                            6303 non-null   object
#  15  host_response_rate                            6303 non-null   object
#  16  host_acceptance_rate                          6723 non-null   object
#  17  host_is_superhost                             7563 non-null   object
#  18  host_thumbnail_url                            7563 non-null   object
#  19  host_picture_url                              7563 non-null   object
#  20  host_neighbourhood                            6962 non-null   object
#  21  host_listings_count                           7563 non-null   float64
#  22  host_total_listings_count                     7563 non-null   float64
#  23  host_verifications                            7571 non-null   object
#  24  host_has_profile_pic                          7563 non-null   object
#  25  host_identity_verified                        7563 non-null   object
#  26  neighbourhood                                 5340 non-null   object
#  27  neighbourhood_cleansed                        7571 non-null   object
#  28  neighbourhood_group_cleansed                  4335 non-null   object
#  29  latitude                                      7571 non-null   float64
#  30  longitude                                     7571 non-null   float64
#  31  property_type                                 7571 non-null   object
#  32  room_type                                     7571 non-null   object
#  33  accommodates                                  7571 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                7564 non-null   object
#  36  bedrooms                                      6606 non-null   float64
#  37  beds                                          7518 non-null   float64
#  38  amenities                                     7571 non-null   object
#  39  price                                         7571 non-null   object
#  40  minimum_nights                                7571 non-null   int64
#  41  maximum_nights                                7571 non-null   int64
#  42  minimum_minimum_nights                        7570 non-null   float64
#  43  maximum_minimum_nights                        7570 non-null   float64
#  44  minimum_maximum_nights                        7570 non-null   float64
#  45  maximum_maximum_nights                        7570 non-null   float64
#  46  minimum_nights_avg_ntm                        7570 non-null   float64
#  47  maximum_nights_avg_ntm                        7570 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              7571 non-null   object
#  50  availability_30                               7571 non-null   int64
#  51  availability_60                               7571 non-null   int64
#  52  availability_90                               7571 non-null   int64
#  53  availability_365                              7571 non-null   int64
#  54  calendar_last_scraped                         7571 non-null   object
#  55  number_of_reviews                             7571 non-null   int64
#  56  number_of_reviews_ltm                         7571 non-null   int64
#  57  number_of_reviews_l30d                        7571 non-null   int64
#  58  first_review                                  5874 non-null   object
#  59  last_review                                   5874 non-null   object
#  60  review_scores_rating                          5842 non-null   float64
#  61  review_scores_accuracy                        5807 non-null   float64
#  62  review_scores_cleanliness                     5808 non-null   float64
#  63  review_scores_checkin                         5806 non-null   float64
#  64  review_scores_communication                   5809 non-null   float64
#  65  review_scores_location                        5807 non-null   float64
#  66  review_scores_value                           5807 non-null   float64
#  67  license                                       4828 non-null   object
#  68  instant_bookable                              7571 non-null   object
#  69  calculated_host_listings_count                7571 non-null   int64
#  70  calculated_host_listings_count_entire_homes   7571 non-null   int64
#  71  calculated_host_listings_count_private_rooms  7571 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   7571 non-null   int64
#  73  reviews_per_month                             5874 non-null   float64
#  74  city                                          7571 non-null   object
# dtypes: float64(22), int64(17), object(36)
# memory usage: 4.4+ MB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394585 entries, 0 to 123709
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     394585 non-null  int64
#  1   id             394585 non-null  int64
#  2   date           394585 non-null  object
#  3   reviewer_id    394585 non-null  int64
#  4   reviewer_name  394584 non-null  object
#  5   comments       394378 non-null  object
#  6   city           394585 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 24.1+ MB

# %%
reviews.isnull().sum()
# Out:
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      1
# comments         207
# city               0
# dtype: int64

# %% [markdown]
# Looking at the reviewes, we can see that only the comments have nulls.  The only thing that needs to be addressed in this dataset is to change the date from object to datetime.

# %%
pd.options.display.max_rows = 100

# %%
listings.host_identity_verified.sample(10)
# Out:
# 3720    t
# 1890    f
# 2425    t
# 2277    f
# 3185    t
# 2500    f
# 1135    t
# 4327    t
# 3195    t
# 2701    t
# Name: host_identity_verified, dtype: object

# %%
listings.head(5)
# Out:
#      id          listing_url       scrape_id last_scraped  \
# 0  2318  https://www.airb...  20201025051148   2020-10-25
# 1  9419  https://www.airb...  20201025051148   2020-10-25
# 2  9531  https://www.airb...  20201025051148   2020-10-25
# 3  9534  https://www.airb...  20201025051148   2020-10-25
# 4  9596  https://www.airb...  20201025051148   2020-10-25
#
#                   name          description neighborhood_overview  \
# 0  Casa Madrona - U...  Gorgeous, archit...  Madrona is a hid...
# 1  Glorious sun roo...  Keeping you safe...  Lots of restaura...
# 2  The Adorable Swe...  The Sweet Orange...  The neighborhood...
# 3  The Coolest Tang...  Welcome to my de...  The neighborhood...
# 4  the down home , ...  We are in a grea...  if you arrive ea...
#
#            picture_url  host_id             host_url  host_name  host_since  \
# 0  https://a0.musca...     2536  https://www.airb...      Megan  2008-08-26
# 1  https://a0.musca...    30559  https://www.airb...  Angielena  2009-08-09
# 2  https://a0.musca...    31481  https://www.airb...     Cassie  2009-08-13
# 3  https://a0.musca...    31481  https://www.airb...     Cassie  2009-08-13
# 4  https://a0.musca...    14942  https://www.airb...      Joyce  2009-04-26
#
#          host_location           host_about  host_response_time  \
# 0  Seattle, Washing...  I welcome guests...        within a day
# 1  Seattle, Washing...  I am a visual ar...  within a few hours
# 2  Seattle, Washing...  The Sweet Orange...        within a day
# 3  Seattle, Washing...  The Sweet Orange...        within a day
# 4  Seattle, Washing...  I am a therapist...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  78%                 t
# 1               100%                  89%                 t
# 2               100%                  64%                 t
# 3               100%                  64%                 t
# 4                90%                  94%                 f
#
#     host_thumbnail_url     host_picture_url host_neighbourhood  \
# 0  https://a0.musca...  https://a0.musca...              Minor
# 1  https://a0.musca...  https://a0.musca...         Georgetown
# 2  https://a0.musca...  https://a0.musca...       The Junction
# 3  https://a0.musca...  https://a0.musca...       The Junction
# 4  https://a0.musca...  https://a0.musca...        Wallingford
#
#    host_listings_count  host_total_listings_count   host_verifications  \
# 0                  2.0                  2.0        ['email', 'phone...
# 1                  8.0                  8.0        ['email', 'phone...
# 2                  2.0                  2.0        ['email', 'phone...
# 3                  2.0                  2.0        ['email', 'phone...
# 4                  5.0                  5.0        ['email', 'phone...
#
#   host_has_profile_pic host_identity_verified        neighbourhood  \
# 0                    t                    t    Seattle, Washing...
# 1                    t                    t    Seattle, Washing...
# 2                    t                    t    Seattle, Washing...
# 3                    t                    t    Seattle, Washing...
# 4                    t                    t    Seattle, Washing...
#
#   neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 0              Madrona           Central Area          47.61082 -122.29082
# 1           Georgetown    Other neighborhoods          47.55017 -122.31937
# 2       Fairmount Park           West Seattle          47.55539 -122.38474
# 3       Fairmount Park           West Seattle          47.55624 -122.38598
# 4          Wallingford    Other neighborhoods          47.65479 -122.33652
#
#          property_type        room_type  accommodates  bathrooms  \
# 0         Entire house  Entire home/apt             9        NaN
# 1  Private room in ...     Private room             2        NaN
# 2         Entire house  Entire home/apt             4        NaN
# 3   Entire guest suite  Entire home/apt             3        NaN
# 4     Entire apartment  Entire home/apt             4        NaN
#
#    bathrooms_text  bedrooms  beds            amenities    price  \
# 0       2.5 baths       4.0   4.0  ["Children\u2019...  $295.00
# 1  3 shared baths       1.0   2.0  ["Iron", "Hanger...   $55.00
# 2          1 bath       2.0   3.0  ["Iron", "TV", "...  $155.00
# 3          1 bath       2.0   2.0  ["Conditioner", ...  $125.00
# 4          1 bath       1.0   4.0  ["Iron", "TV", "...  $100.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               1            1125                  1.0
# 1               2             180                  2.0
# 2              28            1125                 28.0
# 3               5            1125                  5.0
# 4               4              60                  4.0
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                  2.0                  1125.0                  1125.0
# 1                  2.0                   180.0                   180.0
# 2                 28.0                  1125.0                  1125.0
# 3                  5.0                  1125.0                  1125.0
# 4                  4.0                  1125.0                  1125.0
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                  1.0                  1125.0                  NaN
# 1                  2.0                   180.0                  NaN
# 2                 28.0                  1125.0                  NaN
# 3                  5.0                  1125.0                  NaN
# 4                  4.0                  1125.0                  NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0               26
# 1                t               29               59               89
# 2                t                0                0               19
# 3                t               10               14               40
# 4                t                0                0                6
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                26           2020-10-25                  32
# 1               364           2020-10-25                 148
# 2               294           2020-10-25                  40
# 3               315           2020-10-25                  53
# 4                 6           2020-10-25                  97
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                    4                      0      2008-09-15  2020-02-01
# 1                    2                      0      2010-07-30  2019-12-27
# 2                    1                      0      2012-01-12  2019-12-30
# 3                    8                      0      2012-01-15  2020-08-31
# 4                    4                      1      2011-06-15  2020-09-28
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                100.0                  10.0                    10.0
# 1                 93.0                  10.0                    10.0
# 2                100.0                  10.0                    10.0
# 3                100.0                  10.0                    10.0
# 4                 91.0                   9.0                     9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                 10.0                   10.0                         10.0
# 1                 10.0                   10.0                         10.0
# 2                 10.0                   10.0                         10.0
# 3                 10.0                   10.0                         10.0
# 4                 10.0                    9.0                         10.0
#
#    review_scores_value             license instant_bookable  \
# 0                 10.0  STR-OPLI-19-002837                f
# 1                 10.0  str-opli-19-003039                f
# 2                 10.0  STR-OPLI-19-002182                f
# 3                 10.0  STR-OPLI-19-002182                f
# 4                  9.0  STR-OPLI-19-002622                f
#
#    calculated_host_listings_count  \
# 0                    2
# 1                    8
# 2                    2
# 3                    2
# 4                    2
#
#    calculated_host_listings_count_entire_homes  \
# 0                    2
# 1                    0
# 2                    2
# 3                    2
# 4                    2
#
#    calculated_host_listings_count_private_rooms  \
# 0                    0
# 1                    8
# 2                    0
# 3                    0
# 4                    0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month     city
# 0                    0                                       0.22  Seattle
# 1                    0                                       1.19  Seattle
# 2                    0                                       0.37  Seattle
# 3                    0                                       0.50  Seattle
# 4                    0                                       0.85  Seattle

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'city'],
#       dtype='object')

# %%
percent_missing_listings = listings.isnull().sum()*100 /len(listings)

missing_values_listings = pd.DataFrame({'column_name': listings.columns,
                                 'percent_missing': percent_missing_listings})
missing_values_listings.sort_values('percent_missing', ascending=False)
# Out:
#                               column_name  percent_missing
# calendar_updated         calendar_updated       100.000000
# bathrooms                       bathrooms       100.000000
# neighbourhood_gro...  neighbourhood_gr...        42.742042
# license                           license        36.230353
# host_about                     host_about        30.537578
# neighbourhood               neighbourhood        29.467706
# neighborhood_over...  neighborhood_ove...        29.467706
# review_scores_che...  review_scores_ch...        23.312640
# review_scores_acc...  review_scores_ac...        23.299432
# review_scores_loc...  review_scores_lo...        23.299432
# review_scores_value   review_scores_value        23.299432
# review_scores_cle...  review_scores_cl...        23.286224
# review_scores_com...  review_scores_co...        23.273015
# review_scores_rating  review_scores_ra...        22.837142
# last_review                   last_review        22.414476
# first_review                 first_review        22.414476
# reviews_per_month       reviews_per_month        22.414476
# host_response_time     host_response_time        16.748118
# host_response_rate     host_response_rate        16.748118
# bedrooms                         bedrooms        12.746004
# host_acceptance_rate  host_acceptance_...        11.200634
# host_neighbourhood     host_neighbourhood         8.043852
# beds                                 beds         0.700040
# description                   description         0.515123
# host_location               host_location         0.237749
# host_total_listin...  host_total_listi...         0.105666
# host_is_superhost       host_is_superhost         0.105666
# host_has_profile_pic  host_has_profile...         0.105666
# host_since                     host_since         0.105666
# host_name                       host_name         0.105666
# host_thumbnail_url     host_thumbnail_url         0.105666
# host_picture_url         host_picture_url         0.105666
# host_listings_count   host_listings_count         0.105666
# host_identity_ver...  host_identity_ve...         0.105666
# bathrooms_text             bathrooms_text         0.092458
# minimum_maximum_n...  minimum_maximum_...         0.013208
# maximum_nights_av...  maximum_nights_a...         0.013208
# minimum_nights_av...  minimum_nights_a...         0.013208
# maximum_maximum_n...  maximum_maximum_...         0.013208
# minimum_minimum_n...  minimum_minimum_...         0.013208
# maximum_minimum_n...  maximum_minimum_...         0.013208
# number_of_reviews       number_of_reviews         0.000000
# calculated_host_l...  calculated_host_...         0.000000
# calendar_last_scr...  calendar_last_sc...         0.000000
# calculated_host_l...  calculated_host_...         0.000000
# number_of_reviews...  number_of_review...         0.000000
# number_of_reviews...  number_of_review...         0.000000
# calculated_host_l...  calculated_host_...         0.000000
# calculated_host_l...  calculated_host_...         0.000000
# instant_bookable         instant_bookable         0.000000
# availability_90           availability_90         0.000000
# availability_365         availability_365         0.000000
# id                                     id         0.000000
# availability_60           availability_60         0.000000
# availability_30           availability_30         0.000000
# scrape_id                       scrape_id         0.000000
# last_scraped                 last_scraped         0.000000
# name                                 name         0.000000
# picture_url                   picture_url         0.000000
# host_id                           host_id         0.000000
# host_url                         host_url         0.000000
# host_verifications     host_verifications         0.000000
# neighbourhood_cle...  neighbourhood_cl...         0.000000
# latitude                         latitude         0.000000
# longitude                       longitude         0.000000
# property_type               property_type         0.000000
# room_type                       room_type         0.000000
# accommodates                 accommodates         0.000000
# listing_url                   listing_url         0.000000
# amenities                       amenities         0.000000
# price                               price         0.000000
# minimum_nights             minimum_nights         0.000000
# maximum_nights             maximum_nights         0.000000
# has_availability         has_availability         0.000000
# city                                 city         0.000000

# %% [markdown]
# The following columns are missing data and are not needed for this study.  They can be dropped:  license, square_feet, notes, host_about, thumbnail_url, medium_url, xl_picture_url.
#
# The following columns are not needed for this analysis and will also be dropped:

# %%
percent_missing_reviews =reviews.isnull().sum()*100 /len(reviews)

missing_values_reviews = pd.DataFrame({'column_name': reviews.columns,
                                 'percent_missing': percent_missing_reviews})
missing_values_reviews.sort_values('percent_missing', ascending=False)
# Out:
#                  column_name  percent_missing
# comments            comments         0.052460
# reviewer_name  reviewer_name         0.000253
# listing_id        listing_id         0.000000
# id                        id         0.000000
# date                    date         0.000000
# reviewer_id      reviewer_id         0.000000
# city                    city         0.000000

# %%
percent_missing_calendar = calendar.isnull().sum()*100 /len(calendar)

missing_values_calendar = pd.DataFrame({'column_name': calendar.columns,
                                 'percent_missing': percent_missing_calendar})
missing_values_calendar.sort_values('percent_missing', ascending=False)
# Out:
#                    column_name  percent_missing
# listing_id          listing_id              0.0
# date                      date              0.0
# available            available              0.0
# price                    price              0.0
# adjusted_price  adjusted_price              0.0
# minimum_nights  minimum_nights              0.0
# maximum_nights  maximum_nights              0.0
# city                      city              0.0

# %%
calendar.available.value_counts()
# Out:
# t    1512125
# f    1250925
# Name: available, dtype: int64

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2763050 entries, 0 to 1180774
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
#  7   city            object
# dtypes: int64(3), object(5)
# memory usage: 189.7+ MB

# %%
check_avail = calendar.query('available == "t"')['price']!="NaN"
check_avail.sample(50)
# Out:
# 1235598    True
# 256702     True
# 13426      True
# 1294256    True
# 1160301    True
# 271835     True
# 675826     True
# 1151324    True
# 701330     True
# 1066410    True
# 595570     True
# 245998     True
# 70660      True
# 772434     True
# 1427473    True
# 669468     True
# 216155     True
# 440102     True
# 799341     True
# 147056     True
# 1064011    True
# 756386     True
# 539069     True
# 198340     True
# 1038862    True
# 477814     True
# 471165     True
# 685877     True
# 1432328    True
# 408618     True
# 956372     True
# 101259     True
# 803437     True
# 972266     True
# 137633     True
# 970140     True
# 702474     True
# 215937     True
# 1098823    True
# 437279     True
# 1159398    True
# 291882     True
# 11788      True
# 1390422    True
# 975709     True
# 1284687    True
# 853240     True
# 697207     True
# 779334     True
# 555680     True
# Name: price, dtype: bool

# %% [markdown]
# Notice that there are 42% mssing price information.  I decided to check to see if availability o='t' indicated that the price would be NaN.  This is not true.  Therefore, we will drop the NaNs.

# %%
# Using describe with include = 'all' allows us to see information about every variable
calendar.describe(include = 'all')
# Out:
#           listing_id        date available    price adjusted_price  \
# count   2.763050e+06     2763050   2763050  2763050        2763050
# unique           NaN         381         2     1936           1936
# top              NaN  2021-06-18         t   $99.00         $99.00
# freq             NaN        7570   1512125    65818          64728
# mean    2.685165e+07         NaN       NaN      NaN            NaN
# std     1.440816e+07         NaN       NaN      NaN            NaN
# min     2.318000e+03         NaN       NaN      NaN            NaN
# 25%     1.491782e+07         NaN       NaN      NaN            NaN
# 50%     2.761961e+07         NaN       NaN      NaN            NaN
# 75%     4.089590e+07         NaN       NaN      NaN            NaN
# max     4.633063e+07         NaN       NaN      NaN            NaN
#
#         minimum_nights  maximum_nights     city
# count     2.763050e+06    2.763050e+06  2763050
# unique             NaN             NaN        2
# top                NaN             NaN  Seattle
# freq               NaN             NaN  1582275
# mean      3.648192e+01    5.666567e+05      NaN
# std       9.817474e+01    3.485330e+07      NaN
# min       1.000000e+00    1.000000e+00      NaN
# 25%       2.000000e+00    3.650000e+02      NaN
# 50%       4.000000e+00    1.125000e+03      NaN
# 75%       3.000000e+01    1.125000e+03      NaN
# max       1.000000e+03    2.147484e+09      NaN

# %%
# Using describe with include = 'all' allows us to see information about every variable
listings.describe(include = 'all')
# Out:
#                   id          listing_url     scrape_id last_scraped  \
# count   7.571000e+03                 7571  7.571000e+03         7571
# unique           NaN                 7571           NaN            2
# top              NaN  https://www.airb...           NaN   2020-10-25
# freq             NaN                    1           NaN         4335
# mean    2.685362e+07                  NaN  2.020106e+13          NaN
# std     1.440917e+07                  NaN  4.204782e+07          NaN
# min     2.318000e+03                  NaN  2.020103e+13          NaN
# 25%     1.491793e+07                  NaN  2.020103e+13          NaN
# 50%     2.762597e+07                  NaN  2.020103e+13          NaN
# 75%     4.089615e+07                  NaN  2.020111e+13          NaN
# max     4.633063e+07                  NaN  2.020111e+13          NaN
#
#                        name          description neighborhood_overview  \
# count                  7571                 7532                 5340
# unique                 6984                 6325                 3912
# top     Live + Work + St...  Stay for 30+ nig...  Downtown’s Theat...
# freq                     51                   64                   41
# mean                    NaN                  NaN                  NaN
# std                     NaN                  NaN                  NaN
# min                     NaN                  NaN                  NaN
# 25%                     NaN                  NaN                  NaN
# 50%                     NaN                  NaN                  NaN
# 75%                     NaN                  NaN                  NaN
# max                     NaN                  NaN                  NaN
#
#                 picture_url       host_id             host_url host_name  \
# count                  7571  7.571000e+03                 7571      7563
# unique                 7245           NaN                 3659      1941
# top     https://a0.musca...           NaN  https://www.airb...       Kia
# freq                     12           NaN                  350       510
# mean                    NaN  1.006440e+08                  NaN       NaN
# std                     NaN  1.149361e+08                  NaN       NaN
# min                     NaN  2.536000e+03                  NaN       NaN
# 25%                     NaN  1.139086e+07                  NaN       NaN
# 50%                     NaN  4.434127e+07                  NaN       NaN
# 75%                     NaN  1.631900e+08                  NaN       NaN
# max                     NaN  3.736751e+08                  NaN       NaN
#
#         host_since        host_location           host_about  \
# count         7563                 7553                 5259
# unique        2161                  242                 2508
# top     2020-07-28  Seattle, Washing...  Live free. Make ...
# freq           350                 3174                  173
# mean           NaN                  NaN                  NaN
# std            NaN                  NaN                  NaN
# min            NaN                  NaN                  NaN
# 25%            NaN                  NaN                  NaN
# 50%            NaN                  NaN                  NaN
# 75%            NaN                  NaN                  NaN
# max            NaN                  NaN                  NaN
#
#        host_response_time host_response_rate host_acceptance_rate  \
# count                6303               6303                 6723
# unique                  4                 45                   77
# top        within an hour               100%                 100%
# freq                 4236               4015                 2240
# mean                  NaN                NaN                  NaN
# std                   NaN                NaN                  NaN
# min                   NaN                NaN                  NaN
# 25%                   NaN                NaN                  NaN
# 50%                   NaN                NaN                  NaN
# 75%                   NaN                NaN                  NaN
# max                   NaN                NaN                  NaN
#
#        host_is_superhost   host_thumbnail_url     host_picture_url  \
# count               7563                 7563                 7563
# unique                 2                 3647                 3647
# top                    f  https://a0.musca...  https://a0.musca...
# freq                4313                  350                  350
# mean                 NaN                  NaN                  NaN
# std                  NaN                  NaN                  NaN
# min                  NaN                  NaN                  NaN
# 25%                  NaN                  NaN                  NaN
# 50%                  NaN                  NaN                  NaN
# 75%                  NaN                  NaN                  NaN
# max                  NaN                  NaN                  NaN
#
#          host_neighbourhood  host_listings_count  host_total_listings_count  \
# count                  6962          7563.000000          7563.000000
# unique                  208                  NaN                  NaN
# top     Buckman Neighbor...                  NaN                  NaN
# freq                    350                  NaN                  NaN
# mean                    NaN           189.711490           189.711490
# std                     NaN           467.368076           467.368076
# min                     NaN             0.000000             0.000000
# 25%                     NaN             1.000000             1.000000
# 50%                     NaN             3.000000             3.000000
# 75%                     NaN            28.000000            28.000000
# max                     NaN          1646.000000          1646.000000
#
#         host_verifications host_has_profile_pic host_identity_verified  \
# count                 7571                 7563                 7563
# unique                 227                    2                    2
# top     ['email', 'phone']                    t                    t
# freq                   987                 7558                 6308
# mean                   NaN                  NaN                  NaN
# std                    NaN                  NaN                  NaN
# min                    NaN                  NaN                  NaN
# 25%                    NaN                  NaN                  NaN
# 50%                    NaN                  NaN                  NaN
# 75%                    NaN                  NaN                  NaN
# max                    NaN                  NaN                  NaN
#
#               neighbourhood neighbourhood_cleansed  \
# count                  5340                 7571
# unique                   38                  112
# top     Seattle, Washing...           Dorchester
# freq                   3035                  396
# mean                    NaN                  NaN
# std                     NaN                  NaN
# min                     NaN                  NaN
# 25%                     NaN                  NaN
# 50%                     NaN                  NaN
# 75%                     NaN                  NaN
# max                     NaN                  NaN
#
#        neighbourhood_group_cleansed     latitude    longitude  \
# count                  4335          7571.000000  7571.000000
# unique                   17                  NaN          NaN
# top                Downtown                  NaN          NaN
# freq                    842                  NaN          NaN
# mean                    NaN            45.364961  -100.428438
# std                     NaN             2.616160    25.356080
# min                     NaN            42.235200  -122.418760
# 25%                     NaN            42.349225  -122.339910
# 50%                     NaN            47.567540  -122.296460
# 75%                     NaN            47.624795   -71.080035
# max                     NaN            47.734890   -70.997010
#
#            property_type        room_type  accommodates  bathrooms  \
# count               7571             7571   7571.000000        0.0
# unique                56                4           NaN        NaN
# top     Entire apartment  Entire home/apt           NaN        NaN
# freq                2452             5566           NaN        NaN
# mean                 NaN              NaN      3.434949        NaN
# std                  NaN              NaN      2.200598        NaN
# min                  NaN              NaN      1.000000        NaN
# 25%                  NaN              NaN      2.000000        NaN
# 50%                  NaN              NaN      3.000000        NaN
# 75%                  NaN              NaN      4.000000        NaN
# max                  NaN              NaN     16.000000        NaN
#
#        bathrooms_text     bedrooms         beds            amenities    price  \
# count            7564  6606.000000  7518.000000                 7571     7571
# unique             26          NaN          NaN                 6228      468
# top            1 bath          NaN          NaN  ["Iron", "TV", "...  $100.00
# freq             4426          NaN          NaN                   47      158
# mean              NaN     1.502876     1.777068                  NaN      NaN
# std               NaN     0.878496     1.351902                  NaN      NaN
# min               NaN     1.000000     0.000000                  NaN      NaN
# 25%               NaN     1.000000     1.000000                  NaN      NaN
# 50%               NaN     1.000000     1.000000                  NaN      NaN
# 75%               NaN     2.000000     2.000000                  NaN      NaN
# max               NaN    13.000000    22.000000                  NaN      NaN
#
#         minimum_nights  maximum_nights  minimum_minimum_nights  \
# count      7571.000000     7571.000000          7570.000000
# unique             NaN             NaN                  NaN
# top                NaN             NaN                  NaN
# freq               NaN             NaN                  NaN
# mean         24.595166      672.592392            25.149934
# std          35.659227      511.827954            49.257892
# min           1.000000        1.000000             1.000000
# 25%           2.000000      100.000000             2.000000
# 50%           4.000000     1125.000000             3.000000
# 75%          30.000000     1125.000000            30.000000
# max        1000.000000    10000.000000          1000.000000
#
#         maximum_minimum_nights  minimum_maximum_nights  \
# count           7570.000000             7570.000000
# unique                  NaN                     NaN
# top                     NaN                     NaN
# freq                    NaN                     NaN
# mean              39.675165              837.274373
# std              101.962213              462.974794
# min                1.000000                1.000000
# 25%                2.000000              365.000000
# 50%                6.000000             1125.000000
# 75%               30.000000             1125.000000
# max             1000.000000            10000.000000
#
#         maximum_maximum_nights  minimum_nights_avg_ntm  \
# count          7.570000e+03             7570.000000
# unique                  NaN                     NaN
# top                     NaN                     NaN
# freq                    NaN                     NaN
# mean           5.682177e+05               36.468203
# std            3.490343e+07               97.003213
# min            1.000000e+00                1.000000
# 25%            3.650000e+02                2.000000
# 50%            1.125000e+03                5.000000
# 75%            1.125000e+03               30.000000
# max            2.147484e+09             1000.000000
#
#         maximum_nights_avg_ntm  calendar_updated has_availability  \
# count          7.570000e+03                  0.0             7571
# unique                  NaN                  NaN                1
# top                     NaN                  NaN                t
# freq                    NaN                  NaN             7571
# mean           5.669275e+05                  NaN              NaN
# std            3.482446e+07                  NaN              NaN
# min            1.000000e+00                  NaN              NaN
# 25%            3.650000e+02                  NaN              NaN
# 50%            1.125000e+03                  NaN              NaN
# 75%            1.125000e+03                  NaN              NaN
# max            2.142625e+09                  NaN              NaN
#
#         availability_30  availability_60  availability_90  availability_365  \
# count       7571.000000      7571.000000      7571.000000       7571.000000
# unique              NaN              NaN              NaN               NaN
# top                 NaN              NaN              NaN               NaN
# freq                NaN              NaN              NaN               NaN
# mean          13.046757        31.006604        51.637300        194.094043
# std           12.085218        23.532640        33.858471        131.591383
# min            0.000000         0.000000         0.000000          0.000000
# 25%            0.000000         3.000000        21.000000         80.000000
# 50%           11.000000        34.000000        59.000000        179.000000
# 75%           25.000000        55.000000        85.000000        335.000000
# max           30.000000        60.000000        90.000000        365.000000
#
#        calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# count                  7571         7571.000000          7571.000000
# unique                    2                 NaN                  NaN
# top              2020-10-25                 NaN                  NaN
# freq                   4335                 NaN                  NaN
# mean                    NaN           52.117950             8.394003
# std                     NaN           82.400412            14.561606
# min                     NaN            0.000000             0.000000
# 25%                     NaN            1.000000             0.000000
# 50%                     NaN           15.000000             2.000000
# 75%                     NaN           69.000000            11.000000
# max                     NaN          909.000000           250.000000
#
#         number_of_reviews_l30d first_review last_review  review_scores_rating  \
# count           7571.000000            5874        5874          5842.000000
# unique                  NaN            2125         901                  NaN
# top                     NaN      2019-06-30  2020-10-18                  NaN
# freq                    NaN              14         175                  NaN
# mean               0.734249             NaN         NaN            94.580623
# std                1.921488             NaN         NaN             8.082549
# min                0.000000             NaN         NaN            20.000000
# 25%                0.000000             NaN         NaN            93.000000
# 50%                0.000000             NaN         NaN            97.000000
# 75%                1.000000             NaN         NaN            99.000000
# max               80.000000             NaN         NaN           100.000000
#
#         review_scores_accuracy  review_scores_cleanliness  \
# count           5807.000000             5808.000000
# unique                  NaN                     NaN
# top                     NaN                     NaN
# freq                    NaN                     NaN
# mean               9.685896                9.581784
# std                0.779636                0.832973
# min                2.000000                2.000000
# 25%               10.000000                9.000000
# 50%               10.000000               10.000000
# 75%               10.000000               10.000000
# max               10.000000               10.000000
#
#         review_scores_checkin  review_scores_communication  \
# count           5806.000000            5809.000000
# unique                  NaN                    NaN
# top                     NaN                    NaN
# freq                    NaN                    NaN
# mean               9.806063               9.772939
# std                0.666618               0.685282
# min                2.000000               2.000000
# 25%               10.000000              10.000000
# 50%               10.000000              10.000000
# 75%               10.000000              10.000000
# max               10.000000              10.000000
#
#         review_scores_location  review_scores_value              license  \
# count            5807.00000             5807.000000                 4828
# unique                  NaN                     NaN                 2936
# top                     NaN                     NaN  Exempt: This lis...
# freq                    NaN                     NaN                  219
# mean                9.73928                9.419494                  NaN
# std                 0.62573                0.879799                  NaN
# min                 2.00000                2.000000                  NaN
# 25%                10.00000                9.000000                  NaN
# 50%                10.00000               10.000000                  NaN
# 75%                10.00000               10.000000                  NaN
# max                10.00000               10.000000                  NaN
#
#        instant_bookable  calculated_host_listings_count  \
# count              7571          7571.000000
# unique                2                  NaN
# top                   t                  NaN
# freq               3893                  NaN
# mean                NaN            31.805970
# std                 NaN            76.598973
# min                 NaN             1.000000
# 25%                 NaN             1.000000
# 50%                 NaN             3.000000
# 75%                 NaN            19.000000
# max                 NaN           350.000000
#
#         calculated_host_listings_count_entire_homes  \
# count           7571.000000
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean              29.463611
# std               76.825788
# min                0.000000
# 25%                1.000000
# 50%                1.000000
# 75%               12.000000
# max              350.000000
#
#         calculated_host_listings_count_private_rooms  \
# count           7571.000000
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean               2.166028
# std                6.121710
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                1.000000
# max               40.000000
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count           7571.000000                                5874.000000
# unique                  NaN                                        NaN
# top                     NaN                                        NaN
# freq                    NaN                                        NaN
# mean               0.092062                                   1.856491
# std                1.206589                                   1.976118
# min                0.000000                                   0.010000
# 25%                0.000000                                   0.450000
# 50%                0.000000                                   1.270000
# 75%                0.000000                                   2.720000
# max               17.000000                                  38.140000
#
#            city
# count      7571
# unique        2
# top     Seattle
# freq       4335
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
listings[listings['minimum_nights']>30].sort_values('minimum_nights', ascending=False).head(10)
# Out:
#             id          listing_url       scrape_id last_scraped  \
# 250    5222368  https://www.airb...  20201110041432   2020-11-10
# 1374  24131246  https://www.airb...  20201110041432   2020-11-10
# 1572  28635984  https://www.airb...  20201110041432   2020-11-10
# 849   11254431  https://www.airb...  20201025051148   2020-10-25
# 2825  44232647  https://www.airb...  20201110041432   2020-11-10
# 2900  44889565  https://www.airb...  20201110041432   2020-11-10
# 2331  40530153  https://www.airb...  20201110041432   2020-11-10
# 978   13224936  https://www.airb...  20201025051148   2020-10-25
# 456    5346780  https://www.airb...  20201025051148   2020-10-25
# 1386  18137728  https://www.airb...  20201025051148   2020-10-25
#
#                      name          description neighborhood_overview  \
# 250   Newly-Renovated ...  This cozy 2 bedr...  Very quiet neigh...
# 1374  Boston Beautiful...  Very Large Moder...                  NaN
# 1572  Beautiful apartm...  Large private ro...                  NaN
# 849   Master suite in ...  Master suite wit...                  NaN
# 2825  Luxury Full Conc...  Highly coveted 1...  The heart of Cop...
# 2900  Large, Sun-Drenc...  Large and Sunny ...                  NaN
# 2331  One bedroom avai...  Information requ...  Jamaica plain is...
# 978   7 month lease. F...  Beautiful 2 bedr...  This is one of t...
# 456   Airy Oasis Steps...  Admire this ligh...  Between South La...
# 1386  Stately Squire P...  Near downtown Se...  Grand turn-of-th...
#
#               picture_url    host_id             host_url host_name  \
# 250   https://a0.musca...    1532353  https://www.airb...     Diana
# 1374  https://a0.musca...   93115614  https://www.airb...     Selim
# 1572  https://a0.musca...  213613694  https://www.airb...    Manuel
# 849   https://a0.musca...   19984963  https://www.airb...     Sarah
# 2825  https://a0.musca...   55527201  https://www.airb...      Lisa
# 2900  https://a0.musca...   91174308  https://www.airb...    Taitum
# 2331  https://a0.musca...  260850604  https://www.airb...       Kat
# 978   https://a0.musca...   13960065  https://www.airb...      Alan
# 456   https://a0.musca...    6746292  https://www.airb...     Susie
# 1386  https://a0.musca...  125033458  https://www.airb...     Misty
#
#       host_since        host_location           host_about host_response_time  \
# 250   2011-12-24  Boston, Massachu...  I am a 5th year ...                NaN
# 1374  2016-09-02                   US                  NaN                NaN
# 1572  2018-09-04  Boston, Massachu...  Me and my wife M...                NaN
# 849   2014-08-13                   US                  NaN                NaN
# 2825  2016-01-21  Boston, Massachu...  Professional gal...                NaN
# 2900  2016-08-21  Pittsburgh, Penn...                  NaN                NaN
# 2331  2019-05-09  Boston, Massachu...                  NaN                NaN
# 978   2014-04-06  Seattle, Washing...                  NaN                NaN
# 456   2013-06-05  Tacoma, Washingt...  Dog lover & worl...     within an hour
# 1386  2017-04-09  Seattle, Washing...  Hello, happy tra...     within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 250                 NaN                  NaN                 f
# 1374                NaN                  NaN                 f
# 1572                NaN                  NaN                 f
# 849                 NaN                  NaN                 f
# 2825                NaN                  NaN                 f
# 2900                NaN                  NaN                 f
# 2331                NaN                  NaN                 f
# 978                 NaN                 100%                 t
# 456                100%                  97%                 t
# 1386               100%                 100%                 f
#
#        host_thumbnail_url     host_picture_url   host_neighbourhood  \
# 250   https://a0.musca...  https://a0.musca...                  NaN
# 1374  https://a0.musca...  https://a0.musca...     Allston-Brighton
# 1572  https://a0.musca...  https://a0.musca...                  NaN
# 849   https://a0.musca...  https://a0.musca...                  NaN
# 2825  https://a0.musca...  https://a0.musca...  Prudential / St....
# 2900  https://a0.musca...  https://a0.musca...            North End
# 2331  https://a0.musca...  https://a0.musca...        Jamaica Plain
# 978   https://a0.musca...  https://a0.musca...                  NaN
# 456   https://a0.musca...  https://a0.musca...             Belltown
# 1386  https://a0.musca...  https://a0.musca...                Minor
#
#       host_listings_count  host_total_listings_count   host_verifications  \
# 250                   1.0                  1.0        ['email', 'phone...
# 1374                  1.0                  1.0        ['email', 'phone...
# 1572                  1.0                  1.0        ['email', 'phone...
# 849                   1.0                  1.0        ['email', 'phone...
# 2825                  0.0                  0.0        ['email', 'phone...
# 2900                  0.0                  0.0        ['email', 'phone...
# 2331                  0.0                  0.0        ['email', 'phone...
# 978                   4.0                  4.0        ['email', 'phone...
# 456                   5.0                  5.0        ['email', 'phone...
# 1386                  1.0                  1.0        ['email', 'phone...
#
#      host_has_profile_pic host_identity_verified        neighbourhood  \
# 250                     t                    t    Boston, Massachu...
# 1374                    t                    f                    NaN
# 1572                    t                    t                    NaN
# 849                     t                    t                    NaN
# 2825                    t                    t    Boston, Massachu...
# 2900                    t                    f                    NaN
# 2331                    t                    f    Boston, Massachu...
# 978                     t                    t    Seattle, Washing...
# 456                     t                    f    Seattle, Washing...
# 1386                    t                    f    Seattle, Washing...
#
#      neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 250          Mission Hill                    NaN          42.32896  -71.10728
# 1374              Allston                    NaN          42.35359  -71.12697
# 1572           Dorchester                    NaN          42.30157  -71.08153
# 849         West Woodland                Ballard          47.66736 -122.36834
# 2825             Back Bay                    NaN          42.34984  -71.07305
# 2900            North End                    NaN          42.36228  -71.05401
# 2331        Jamaica Plain                    NaN          42.32243  -71.10051
# 978   Harrison/Denny-B...           Central Area          47.61996 -122.28641
# 456              Belltown               Downtown          47.61645 -122.33694
# 1386                Minor           Central Area          47.61001 -122.30573
#
#             property_type        room_type  accommodates  bathrooms  \
# 250   Private room in ...     Private room             1        NaN
# 1374   Entire condominium  Entire home/apt             3        NaN
# 1572         Entire house  Entire home/apt            12        NaN
# 849   Private room in ...     Private room             2        NaN
# 2825   Entire condominium  Entire home/apt             4        NaN
# 2900     Entire apartment  Entire home/apt             4        NaN
# 2331  Private room in ...     Private room             1        NaN
# 978          Entire house  Entire home/apt             2        NaN
# 456    Entire condominium  Entire home/apt             3        NaN
# 1386         Entire house  Entire home/apt             4        NaN
#
#      bathrooms_text  bedrooms  beds            amenities    price  \
# 250          1 bath       1.0   1.0  ["Wifi", "Washer...   $75.00
# 1374         1 bath       NaN   1.0  ["Washer", "Kitc...  $135.00
# 1572         1 bath       5.0   5.0  ["Luggage dropof...  $300.00
# 849       1.5 baths       1.0   1.0  ["Wifi", "Shampo...  $140.00
# 2825         1 bath       1.0   1.0  ["Washer", "Air ...  $240.00
# 2900        2 baths       2.0   2.0  ["Washer", "Air ...  $108.00
# 2331         1 bath       1.0   1.0  ["Wifi", "Washer...   $19.00
# 978         2 baths       2.0   2.0  ["Free street pa...  $140.00
# 456          1 bath       1.0   1.0  ["Dishwasher", "...   $80.00
# 1386      1.5 baths       2.0   2.0  ["Bathtub", "Chi...  $160.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 250             1000            1000               1000.0
# 1374             600            1125                600.0
# 1572             400             400                400.0
# 849              365             365                365.0
# 2825             364            1125                364.0
# 2900             360            1125                360.0
# 2331             271             271                271.0
# 978              210             210                210.0
# 456              183             183                183.0
# 1386             182             365                  2.0
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 250                1000.0                  1000.0                  1000.0
# 1374                600.0                  1125.0                  1125.0
# 1572                400.0                  1125.0                  1125.0
# 849                 365.0                   365.0                   365.0
# 2825                364.0                  1125.0                  1125.0
# 2900                360.0                  1125.0                  1125.0
# 2331                271.0                   271.0                   271.0
# 978                 210.0                   210.0                   210.0
# 456                 183.0                  1125.0                  1125.0
# 1386                182.0                   365.0                   365.0
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 250                1000.0                  1000.0                  NaN
# 1374                600.0                  1125.0                  NaN
# 1572                400.0                  1125.0                  NaN
# 849                 365.0                   365.0                  NaN
# 2825                364.0                  1125.0                  NaN
# 2900                360.0                  1125.0                  NaN
# 2331                271.0                   271.0                  NaN
# 978                 210.0                   210.0                  NaN
# 456                 183.0                  1125.0                  NaN
# 1386                130.7                   365.0                  NaN
#
#      has_availability  availability_30  availability_60  availability_90  \
# 250                 t                0                0                0
# 1374                t                0                0                0
# 1572                t               29               59               89
# 849                 t               30               60               90
# 2825                t               30               60               90
# 2900                t               30               60               90
# 2331                t                0                0                0
# 978                 t                0                0                0
# 456                 t                0                0               22
# 1386                t               23               53               83
#
#       availability_365 calendar_last_scraped  number_of_reviews  \
# 250                  0           2020-11-10                   0
# 1374                 0           2020-11-10                   0
# 1572               364           2020-11-10                   0
# 849                365           2020-10-25                   0
# 2825               365           2020-11-10                   0
# 2900               365           2020-11-10                   0
# 2331                 0           2020-11-10                   0
# 978                 11           2020-10-25                   0
# 456                297           2020-10-25                 101
# 1386                83           2020-10-25                  22
#
#       number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 250                     0                      0             NaN         NaN
# 1374                    0                      0             NaN         NaN
# 1572                    0                      0             NaN         NaN
# 849                     0                      0             NaN         NaN
# 2825                    0                      0             NaN         NaN
# 2900                    0                      0             NaN         NaN
# 2331                    0                      0             NaN         NaN
# 978                     0                      0             NaN         NaN
# 456                     1                      0      2015-03-28  2019-11-22
# 1386                    1                      0      2017-04-16  2020-08-23
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 250                   NaN                   NaN                     NaN
# 1374                  NaN                   NaN                     NaN
# 1572                  NaN                   NaN                     NaN
# 849                   NaN                   NaN                     NaN
# 2825                  NaN                   NaN                     NaN
# 2900                  NaN                   NaN                     NaN
# 2331                  NaN                   NaN                     NaN
# 978                   NaN                   NaN                     NaN
# 456                  98.0                  10.0                    10.0
# 1386                 99.0                  10.0                    10.0
#
#       review_scores_checkin  review_scores_communication  \
# 250                   NaN                    NaN
# 1374                  NaN                    NaN
# 1572                  NaN                    NaN
# 849                   NaN                    NaN
# 2825                  NaN                    NaN
# 2900                  NaN                    NaN
# 2331                  NaN                    NaN
# 978                   NaN                    NaN
# 456                  10.0                   10.0
# 1386                 10.0                   10.0
#
#       review_scores_location  review_scores_value             license  \
# 250                   NaN                     NaN                 NaN
# 1374                  NaN                     NaN                 NaN
# 1572                  NaN                     NaN                 NaN
# 849                   NaN                     NaN                 NaN
# 2825                  NaN                     NaN                 NaN
# 2900                  NaN                     NaN                 NaN
# 2331                  NaN                     NaN                 NaN
# 978                   NaN                     NaN                 NaN
# 456                  10.0                    10.0              817508
# 1386                 10.0                    10.0  STR-OPLI-19-003068
#
#      instant_bookable  calculated_host_listings_count  \
# 250                 f                    1
# 1374                f                    1
# 1572                t                    1
# 849                 f                    1
# 2825                t                    1
# 2900                t                    1
# 2331                t                    1
# 978                 f                    2
# 456                 f                    2
# 1386                f                    1
#
#       calculated_host_listings_count_entire_homes  \
# 250                     0
# 1374                    1
# 1572                    1
# 849                     0
# 2825                    1
# 2900                    1
# 2331                    0
# 978                     2
# 456                     2
# 1386                    1
#
#       calculated_host_listings_count_private_rooms  \
# 250                     1
# 1374                    0
# 1572                    0
# 849                     1
# 2825                    0
# 2900                    0
# 2331                    1
# 978                     0
# 456                     0
# 1386                    0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month     city
# 250                     0                                        NaN   Boston
# 1374                    0                                        NaN   Boston
# 1572                    0                                        NaN   Boston
# 849                     0                                        NaN  Seattle
# 2825                    0                                        NaN   Boston
# 2900                    0                                        NaN   Boston
# 2331                    0                                        NaN   Boston
# 978                     0                                        NaN  Seattle
# 456                     0                                       1.49  Seattle
# 1386                    0                                       0.51  Seattle

# %%
listings['availability_365'].describe()
# Out:
# count    7571.000000
# mean      194.094043
# std       131.591383
# min         0.000000
# 25%        80.000000
# 50%       179.000000
# 75%       335.000000
# max       365.000000
# Name: availability_365, dtype: float64

# %%
# Using describe with include = 'all' allows us to see information about every variable
reviews.describe(include = 'all')
# Out:
#           listing_id            id        date   reviewer_id reviewer_name  \
# count   3.945850e+05  3.945850e+05      394585  3.945850e+05        394584
# unique           NaN           NaN        3509           NaN         47128
# top              NaN           NaN  2019-09-02           NaN       Michael
# freq             NaN           NaN         754           NaN          3595
# mean    1.478586e+07  3.344656e+08         NaN  8.975571e+07           NaN
# std     1.056850e+07  1.942432e+08         NaN  8.413001e+07           NaN
# min     2.318000e+03  1.460000e+02         NaN  1.500000e+01           NaN
# 25%     5.900224e+06  1.689626e+08         NaN  2.189754e+07           NaN
# 50%     1.384306e+07  3.189044e+08         NaN  6.193293e+07           NaN
# 75%     2.165054e+07  5.056997e+08         NaN  1.380903e+08           NaN
# max     4.611752e+07  7.078591e+08         NaN  3.740717e+08           NaN
#
#             comments     city
# count         394378   394585
# unique        384236        2
# top     Great place!  Seattle
# freq             420   270875
# mean             NaN      NaN
# std              NaN      NaN
# min              NaN      NaN
# 25%              NaN      NaN
# 50%              NaN      NaN
# 75%              NaN      NaN
# max              NaN      NaN

# %% [markdown]
# ### Cleaning
#
# We start by making a copy of the data

# %%
# resetting the row maximum displayed to 20
pd.options.display.max_rows = 20

# %%
air_reviews = reviews.copy(deep=False )
air_calendar = calendar.copy(deep=False )
air_listings = listings.copy(deep=False )

# %% [markdown]
# ### Code
#
# Let's start by fixing the date variables.

# %%
# This code changes the following columns to datetime.
air_reviews['date'] = pd.to_datetime(air_reviews['date']) 
air_calendar['date'] = pd.to_datetime(air_calendar['date']) 
air_listings['first_review'] = pd.to_datetime(air_listings['first_review']) 
air_listings['last_review'] = pd.to_datetime(air_listings['last_review']) 
air_listings['last_scraped'] = pd.to_datetime(air_listings['last_scraped']) 
air_listings['calendar_last_scraped'] = pd.to_datetime(air_listings['calendar_last_scraped']) 
air_listings['host_since'] = pd.to_datetime(air_listings['host_since'])

# %% [markdown]
# ### Validate

# %%
# identify columns with numeric values
datetime_columns = air_reviews.select_dtypes(include = ['datetime']).columns
datetime_columns
# Out:
# Index(['date'], dtype='object')

# %%
# identify columns with numeric values
air_listings_columns = air_listings.select_dtypes(include = ['datetime']).columns
air_listings_columns
# Out:
# Index(['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review',
#        'last_review'],
#       dtype='object')

# %% [markdown]
# ### Issue
#
# Need to change the following columns from "t" or "f" to "True" or "False" and make boolean:
# host_is_superhost, host_has_profile_pic, host_identity_verified, is_location_exact, has_availability, requires_license,
# instant_bookable, require_guest_profile_pic, require_guest_phone_verification
#
# Also, change availability column in air_calendar to boolean

# %% [markdown]
# ### Code

# %%
var_names = ['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', \
             'has_availability',  'instant_bookable']

for var in var_names:
    air_listings[var].replace('t', True, inplace = True)
    air_listings[var].replace('f', False, inplace = True)
    
air_calendar['available'].replace('t', 1, inplace = True)
air_calendar['available'].replace('f', 0, inplace = True)
air_calendar['available'] = air_calendar['available'].astype('int64')

# %% [markdown]
# ### Validate

# %%
# identify columns with numeric values
datetime_columns = air_listings.select_dtypes(include = ['boolean']).columns
datetime_columns
# Out:
# Index(['has_availability', 'instant_bookable', ' Smoke alarm', ' Essentials',
#        ' Carbon monoxide alarm', ' Heating', ' Hangers', ' Hair dryer',
#        ' Kitchen', ' Shampoo',
#        ...
#        ' Fisher and Paykel stainless steel gas stove',
#        ' Fisher Paykel stainless steel gas stove',
#        ' and Jayson body wash body soap',
#        ' and because it is in the Studio I bought a self defrost because this keeps the room much quieter!  It has the freezer in the refrigerator. refrigerator',
#        ' body wash body soap',
#        ' but I bought new some years ago. It is older but has always worked very good',
#        ' clock radio sound system with Bluetooth and aux',
#        ' double ovens stainless steel oven', ' electric oven gas stove',
#        'Wifi \u2013 60 Mbps'],
#       dtype='object', length=395)

# %%
# identify boolean column in air_calendar
datetime_columns = air_calendar.select_dtypes(include = ['int64']).columns
datetime_columns
# Out:
# Index(['listing_id', 'available', 'minimum_nights', 'maximum_nights'], dtype='object')

# %%
# Need additional code to change air_calendar to boolean
air_calendar['available'] = air_calendar['available'].astype('int64')

# %%
# identify columns with numeric values
numeric_columns = air_listings.select_dtypes(include = ['float']).columns
numeric_columns
# Out:
# Index(['host_listings_count', 'host_total_listings_count', 'latitude',
#        'longitude', 'bathrooms', 'bedrooms', 'beds', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# Additional code is required to change thee three items below to boolean.

# %%
air_listings['host_is_superhost'] = air_listings['host_is_superhost'].astype('boolean')

# %%
air_listings['host_has_profile_pic'] = air_listings['host_has_profile_pic'].astype('boolean')

# %%
air_listings['host_identity_verified'] = air_listings['host_identity_verified'].astype('boolean')

# %% [markdown]
# ### Revalidate

# %%
# identify columns with numeric values
datetime_columns = air_listings.select_dtypes(include = ['bool']).columns
datetime_columns
# Out:
# Index(['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified',
#        'has_availability', 'instant_bookable', ' Smoke alarm', ' Essentials',
#        ' Carbon monoxide alarm', ' Heating', ' Hangers',
#        ...
#        ' Fisher and Paykel stainless steel gas stove',
#        ' Fisher Paykel stainless steel gas stove',
#        ' and Jayson body wash body soap',
#        ' and because it is in the Studio I bought a self defrost because this keeps the room much quieter!  It has the freezer in the refrigerator. refrigerator',
#        ' body wash body soap',
#        ' but I bought new some years ago. It is older but has always worked very good',
#        ' clock radio sound system with Bluetooth and aux',
#        ' double ovens stainless steel oven', ' electric oven gas stove',
#        'Wifi \u2013 60 Mbps'],
#       dtype='object', length=398)

# %% [markdown]
# We can now see that the columns were converted to boolean.

# %% [markdown]
# ### Issue
#
# price, weekly_price, monthly_price, security_deposit, cleaning_fee, and extra_people columns include the $ sign or ','.  This will cause these variables to appear objects.  This will need to be removed and converted to  float64.

# %%
fix_price_cols = ['price', 'host_acceptance_rate', 'host_response_rate']
air_listings[fix_price_cols] = air_listings[fix_price_cols].replace({'\$': '', ',' : '', '\%' : ''}, regex = True)

for fix_price in fix_price_cols:
    air_listings[fix_price] = pd.to_numeric(air_listings[fix_price])

# %% [markdown]
# ### Validate

# %%
air_listings[['price', 'host_acceptance_rate', 'host_response_rate']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7571 entries, 0 to 3235
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price                 7571 non-null   float64
#  1   host_acceptance_rate  6723 non-null   float64
#  2   host_response_rate    6303 non-null   float64
# dtypes: float64(3)
# memory usage: 236.6 KB

# %% [markdown]
# ### Issue
#
# Need to drop null values from the dataset

# %% [markdown]
# ### Code

# %%
air_calendar.shape
# Out:
# (2763050, 8)

# %%
air_calendar.dropna(inplace=True)

# %% [markdown]
# ### Validate

# %%
air_calendar.shape
# Out:
# (2763050, 8)

# %%
air_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2763050 entries, 0 to 1180774
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            datetime64[ns]
#  2   available       int64
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
#  7   city            object
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 189.7+ MB

# %%
air_listings[numeric_columns].hist();

# %%
sns.heatmap(air_listings[numeric_columns].corr(), annot=True)

# %% [markdown]
# ### Issue
# minimum_nights and maximum_nights have values that exceed 365.  To resolve this, values exceeding 365 will be set to the value in availability_365 column.

# %%
air_listings['minimum_nights'] = np.where(air_listings.minimum_nights > 365, air_listings.availability_365,
                                          air_listings.minimum_nights)
air_listings['maximum_nights'] = np.where(air_listings.maximum_nights > 365, air_listings.availability_365,
                                          air_listings.maximum_nights)

air_listings['minimum_minimum_nights'] =  np.where(air_listings.minimum_minimum_nights > 365, air_listings.availability_365,
                                                   air_listings.minimum_minimum_nights)
air_listings['maximum_minimum_nights'] =  np.where(air_listings.maximum_minimum_nights > 365, air_listings.availability_365,
                                                   air_listings.maximum_minimum_nights)
air_listings['maximum_minimum_nights'] =  np.where(air_listings.maximum_minimum_nights > 365, air_listings.availability_365,
                                                   air_listings.maximum_minimum_nights)
air_listings['maximum_maximum_nights'] =  np.where(air_listings.maximum_maximum_nights > 365, air_listings.availability_365,
                                                   air_listings.maximum_maximum_nights)
air_listings['minimum_nights_avg_ntm'] =  np.where(air_listings.minimum_nights_avg_ntm > 365, air_listings.availability_365,
                                                   air_listings.minimum_nights_avg_ntm)
air_listings['maximum_nights_avg_ntm'] =  np.where(air_listings.maximum_nights_avg_ntm > 365, air_listings.availability_365,
                                                   air_listings.maximum_nights_avg_ntm)

# %% [markdown]
# ### Validate

# %%
air_listings[['minimum_nights','maximum_nights','availability_365','minimum_minimum_nights', 'minimum_minimum_nights',
              'minimum_maximum_nights', 'maximum_maximum_nights',
             'maximum_nights_avg_ntm', ]].sort_values('minimum_nights',ascending=False).head(10)
# Out:
#       minimum_nights  maximum_nights  availability_365  \
# 849              365             365               365
# 2825             364             365               365
# 1572             364             364               364
# 2900             360             365               365
# 2331             271             271                 0
# 978              210             210                11
# 456              183             183               297
# 525              182             365               365
# 1386             182             365                83
# 686              180             363               363
#
#       minimum_minimum_nights  minimum_minimum_nights  minimum_maximum_nights  \
# 849                 365.0                   365.0                   365.0
# 2825                364.0                   364.0                  1125.0
# 1572                364.0                   364.0                  1125.0
# 2900                360.0                   360.0                  1125.0
# 2331                271.0                   271.0                   271.0
# 978                 210.0                   210.0                   210.0
# 456                 183.0                   183.0                  1125.0
# 525                 182.0                   182.0                   730.0
# 1386                  2.0                     2.0                   365.0
# 686                 180.0                   180.0                  1125.0
#
#       maximum_maximum_nights  maximum_nights_avg_ntm
# 849                 365.0                   365.0
# 2825                365.0                   365.0
# 1572                364.0                   364.0
# 2900                365.0                   365.0
# 2331                271.0                   271.0
# 978                 210.0                   210.0
# 456                 297.0                   297.0
# 525                 365.0                   365.0
# 1386                365.0                   365.0
# 686                 363.0                   363.0

# %%
air_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7571 entries, 0 to 3235
# Columns: 468 entries, id to Wifi \u2013 60 Mbps
# dtypes: bool(395), boolean(3), datetime64[ns](5), float64(25), int64(17), object(23)
# memory usage: 7.0+ MB

# %% [markdown]
# # Issue
#
# Fix missing values

# %% [markdown]
# ### Code

# %%
bath_test = {'1 bath' : 1, '1 shared bath' : 1.0, '2 baths':  2, '1 private bath': 1, '1.5 baths' : 1.5,
             '2 shared baths' : 2.0, '2.5 baths' : 2.5, '1.5 shared baths' : 1.5, '3 baths' : 3,
             '3.5 baths' : 3.5, '3 shared baths' : 3, '2.5 shared baths': 2.5, '0 shared baths' : 0, 
             '4 baths' : 4.0, 'Half-bath' : 0.5, '4.5 baths' : 4.5, '0 baths' : 0, '3.5 shared baths' : 3.5, 
             '6 baths' : 6, '5 shared baths': 5, '6 shared baths' : 6, '4 shared baths' : 4,  'Shared half-bath' : 0.5,
             'Private half-bath' : 0.5, '11 baths' : 11, '5 baths' : 5}

# %%
air_listings['bathrooms']= air_listings['bathrooms_text'].map(bath_test)

# %%
air_listings['bathrooms'].sample(20)
# Out:
# 780     1.0
# 3834    2.0
# 185     0.5
# 981     1.0
# 3230    2.0
# 222     2.0
# 3018    1.0
# 2223    3.5
# 397     2.0
# 1618    1.0
# 3066    1.0
# 2262    1.0
# 93      2.5
# 2040    1.0
# 21      1.0
# 2225    1.0
# 2451    1.0
# 1133    1.0
# 252     1.0
# 204     1.5
# Name: bathrooms, dtype: float64

# %%
# drop license as it has 100% missing values
air_listings.drop(['license'],axis = 1, inplace=True)

# %%
# drop bathrooms_text as it was only used to create the bathrooms column
air_listings.drop(['bathrooms_text'],axis = 1, inplace=True)

# %%
# change NaN to today's date
air_listings['host_since'] = np.where(air_listings.host_since.isnull(), pd.to_datetime('today'), air_listings.host_since)

# %%
# change NaN to today's date
air_listings['first_review'] = np.where(air_listings.first_review.isnull(), pd.to_datetime('today'),
                                        air_listings.first_review)

# %%
# change NaN to today's date
air_listings['last_review'] = np.where(air_listings.last_review.isnull(), pd.to_datetime('today'),
                                      air_listings.last_review)

# %%
# change missing to unknown
air_listings['neighbourhood_group_cleansed'] = np.where(air_listings.neighbourhood_group_cleansed.isnull(), \
                                               'missing', air_listings.neighbourhood_group_cleansed)

# %%
# change to "False"
air_listings['has_availability'] = np.where(air_listings.has_availability.isnull(), False, air_listings.has_availability)

# %%
# change to "not entered"
air_listings['neighborhood_overview'] = np.where(air_listings.neighborhood_overview.isnull(), 'Not provided',\
                                                 air_listings.neighborhood_overview)

# %%
# change to "not provided"
air_listings['host_about'] = np.where(air_listings.host_about.isnull(), 'Not provided', air_listings.host_about)

# %%
# change to "not provided"
air_listings['host_listings_count'] = np.where(air_listings.host_listings_count.isnull(), 'Not provided', 
                                               air_listings.host_listings_count)

# %%
# change all missin review scores to equal mean
air_listings['review_scores_accuracy'] = np.where(air_listings.review_scores_accuracy.isnull(),\
                                                  air_listings.review_scores_accuracy.mean(), \
                                                  air_listings.review_scores_accuracy)

# %%
air_listings['review_scores_checkin'] = np.where(air_listings.review_scores_checkin.isnull(),\
                                                  air_listings.review_scores_checkin.mean(), \
                                                  air_listings.review_scores_checkin)

# %%
air_listings['review_scores_location'] = np.where(air_listings.review_scores_location.isnull(),\
                                                  air_listings.review_scores_location.mean(), \
                                                  air_listings.review_scores_location)

# %%
air_listings['review_scores_value'] = np.where(air_listings.review_scores_value.isnull(),\
                                                  air_listings.review_scores_value.mean(), \
                                                  air_listings.review_scores_value)

# %%
air_listings['review_scores_cleanliness'] = np.where(air_listings.review_scores_cleanliness.isnull(),\
                                                  air_listings.review_scores_cleanliness.mean(), \
                                                  air_listings.review_scores_cleanliness)

# %%
air_listings['review_scores_communication'] = np.where(air_listings.review_scores_communication.isnull(),\
                                                  air_listings.review_scores_communication.mean(), \
                                                  air_listings.review_scores_communication)

# %%
air_listings['review_scores_rating'] = np.where(air_listings.review_scores_rating.isnull(),\
                                                  air_listings.review_scores_rating.mean(), \
                                                  air_listings.review_scores_rating)

# %%
# change to 0.  If it is missing, it should equal 0
air_listings['minimum_minimum_nights'] = np.where(air_listings.minimum_minimum_nights.isnull(), 0, 
                                                  air_listings.minimum_minimum_nights)

# %%
# change to 0.  If it is missing, it should equal 0
air_listings['maximum_minimum_nights'] = np.where(air_listings.maximum_minimum_nights.isnull(), 0,
                                                  air_listings.maximum_minimum_nights)

# %%
# change to 0.  If it is missing, it should equal 0
air_listings['minimum_maximum_nights'] = np.where(air_listings.minimum_maximum_nights.isnull(), 0,
                                                  air_listings.minimum_maximum_nights)

# %%
# change to 0.  If it is missing, it should equal 0
air_listings['maximum_maximum_nights'] = np.where(air_listings.maximum_maximum_nights.isnull(), 0,
                                                  air_listings.maximum_maximum_nights)

# %%
# change to 0.  If it is missing, it should equal 0
air_listings['minimum_nights_avg_ntm'] = np.where(air_listings.minimum_nights_avg_ntm.isnull(), 0,
                                                  air_listings.minimum_nights_avg_ntm)

# %%
# change to 0.  If it is missing, it should equal 0
air_listings['maximum_nights_avg_ntm'] = np.where(air_listings.maximum_nights_avg_ntm.isnull(), 0,
                                                  air_listings.maximum_nights_avg_ntm)

# %%
# change to 0.  If it is missing, it should equal 0
air_listings['reviews_per_month'] = np.where(air_listings.reviews_per_month.isnull(), 0, air_listings.reviews_per_month)

# %%
# change to mean
air_listings['host_acceptance_rate'] = np.where(air_listings.host_acceptance_rate.isnull(),\
                                                  (air_listings.host_acceptance_rate).mean(), \
                                                  air_listings.host_acceptance_rate)

# %%
# make nulls "not provided"
air_listings['host_response_time'] = np.where(air_listings.host_response_time.isnull(), 'Not provided',\
                                              air_listings.host_response_time)

# %%
air_listings['description'] = np.where(air_listings.description.isnull(), 'Not provided',\
                                              air_listings.description)

# %%
# change nulls to mean.
air_listings['host_response_rate'] = np.where(air_listings.host_response_rate.isnull(),
                                                  (air_listings.host_response_rate*1).mean(), 
                                                  air_listings.host_response_rate)

# %%
# Change to "not identified"
air_listings['neighbourhood'] = np.where(air_listings.neighbourhood.isnull(), 'Not identified',\
                                              air_listings.neighbourhood)

# %%
  # change to not identified
air_listings['host_neighbourhood'] = np.where(air_listings.host_neighbourhood.isnull(), 'Not identified',\
                                              air_listings.host_neighbourhood)

# %%
# change to 1
air_listings['bathrooms'] = np.where(air_listings.bathrooms.isnull(), (air_listings.bathrooms).mean(),
                                     air_listings.bathrooms)

# %%
# change to not identified
air_listings['host_location'] = np.where(air_listings.host_location.isnull(), 'Not identified',\
                                              air_listings.host_location)

# %%
# change to mean
air_listings['bedrooms'] = np.where(air_listings.bedrooms.isnull(),(air_listings.bedrooms).mean(),
                                    air_listings.bedrooms)

# %%
# change to 1 bed
air_listings['beds'] = np.where(air_listings.beds.isnull(), (air_listings.beds).mean(), air_listings.beds)

# %%
# change to not identified
air_listings['property_type'] = np.where(air_listings.property_type.isnull(), 'Not identified',\
                                              air_listings.property_type)

# %%
# change to false
air_listings['host_has_profile_pic'] = np.where(air_listings.host_has_profile_pic.isnull(), False,\
                                              air_listings.host_has_profile_pic)

# %%
# change to unknown
air_listings['host_name'] = np.where(air_listings.host_name.isnull(), 'Unknown',\
                                              air_listings.host_name)

# %%
# change to False
air_listings['host_identity_verified'] = np.where(air_listings.host_identity_verified.isnull(), False,\
                                              air_listings.host_identity_verified)

# %%
# change to False
air_listings['host_is_superhost'] = np.where(air_listings.host_is_superhost.isnull(), False,\
                                              air_listings.host_is_superhost)

# %%
# change to 0
air_listings['host_total_listings_count'] = np.where(air_listings.host_total_listings_count.isnull(), False,\
                                              air_listings.host_total_listings_count)

# %%
# change to no url
air_listings['host_thumbnail_url'] = np.where(air_listings.host_thumbnail_url.isnull(), 'Missing url',\
                                              air_listings.host_thumbnail_url)

# %%
# change to no url
air_listings['host_picture_url'] = np.where(air_listings.host_picture_url.isnull(), 'Missing url',\
                                              air_listings.host_picture_url)

# %%
column_list = air_listings.columns

##We will keep the following variables:



##Check nas

nulls={}
for feat in column_list:
    nulls[feat]=air_listings[feat].isnull().sum()*1.0/len(air_listings[feat])
nulls
# Out:
# {'id': 0.0,
#  'listing_url': 0.0,
#  'scrape_id': 0.0,
#  'last_scraped': 0.0,
#  'name': 0.0,
#  'description': 0.0,
#  'neighborhood_overview': 0.0,
#  'picture_url': 0.0,
#  'host_id': 0.0,
#  'host_url': 0.0,
#  'host_name': 0.0,
#  'host_since': 0.0,
#  'host_location': 0.0,
#  'host_about': 0.0,
#  'host_response_time': 0.0,
#  'host_response_rate': 0.0,
#  'host_acceptance_rate': 0.0,
#  'host_is_superhost': 0.0,
#  'host_thumbnail_url': 0.0,
#  'host_picture_url': 0.0,
#  'host_neighbourhood': 0.0,
#  'host_listings_count': 0.0,
#  'host_total_listings_count': 0.0,
#  'host_verifications': 0.0,
#  'host_has_profile_pic': 0.0,
#  'host_identity_verified': 0.0,
#  'neighbourhood': 0.0,
#  'neighbourhood_cleansed': 0.0,
#  'neighbourhood_group_cleansed': 0.0,
#  'latitude': 0.0,
#  'longitude': 0.0,
#  'property_type': 0.0,
#  'room_type': 0.0,
#  'accommodates': 0.0,
#  'bathrooms': 0.0,
#  'bedrooms': 0.0,
#  'beds': 0.0,
#  'amenities': 0.0,
#  'price': 0.0,
#  'minimum_nights': 0.0,
#  'maximum_nights': 0.0,
#  'minimum_minimum_nights': 0.0,
#  'maximum_minimum_nights': 0.0,
#  'minimum_maximum_nights': 0.0,
#  'maximum_maximum_nights': 0.0,
#  'minimum_nights_avg_ntm': 0.0,
#  'maximum_nights_avg_ntm': 0.0,
#  'calendar_updated': 1.0,
#  'has_availability': 0.0,
#  'availability_30': 0.0,
#  'availability_60': 0.0,
#  'availability_90': 0.0,
#  'availability_365': 0.0,
#  'calendar_last_scraped': 0.0,
#  'number_of_reviews': 0.0,
#  'number_of_reviews_ltm': 0.0,
#  'number_of_reviews_l30d': 0.0,
#  'first_review': 0.0,
#  'last_review': 0.0,
#  'review_scores_rating': 0.0,
#  'review_scores_accuracy': 0.0,
#  'review_scores_cleanliness': 0.0,
#  'review_scores_checkin': 0.0,
#  'review_scores_communication': 0.0,
#  'review_scores_location': 0.0,
#  'review_scores_value': 0.0,
#  'instant_bookable': 0.0,
#  'calculated_host_listings_count': 0.0,
#  'calculated_host_listings_count_entire_homes': 0.0,
#  'calculated_host_listings_count_private_rooms': 0.0,
#  'calculated_host_listings_count_shared_rooms': 0.0,
#  'reviews_per_month': 0.0,
#  'city': 0.0,
#  ' Smoke alarm': 0.0,
#  ' Essentials': 0.0,
#  ' Carbon monoxide alarm': 0.0,
#  ' Heating': 0.0,
#  ' Hangers': 0.0,
#  ' Hair dryer': 0.0,
#  ' Kitchen': 0.0,
#  ' Shampoo': 0.0,
#  ' Wifi': 0.0,
#  ' TV': 0.0,
#  ' Laptop-friendly workspace': 0.0,
#  ' Dryer': 0.0,
#  ' Hot water': 0.0,
#  ' Refrigerator': 0.0,
#  ' Microwave': 0.0,
#  ' Coffee maker': 0.0,
#  ' Dishes and silverware': 0.0,
#  ' Fire extinguisher': 0.0,
#  ' Washer': 0.0,
#  ' Iron': 0.0,
#  ' Cooking basics': 0.0,
#  ' Bed linens': 0.0,
#  ' Stove': 0.0,
#  ' Oven': 0.0,
#  ' Air conditioning': 0.0,
#  ' Long term stays allowed': 0.0,
#  ' Private entrance': 0.0,
#  ' Extra pillows and blankets': 0.0,
#  ' First aid kit': 0.0,
#  ' Dishwasher': 0.0,
#  ' Free street parking': 0.0,
#  ' Free parking on premises': 0.0,
#  ' Patio or balcony': 0.0,
#  ' Cable TV': 0.0,
#  ' Garden or backyard': 0.0,
#  'Iron': 0.0,
#  ' Keypad': 0.0,
#  ' Elevator': 0.0,
#  ' Gym': 0.0,
#  ' BBQ grill': 0.0,
#  ' Lockbox': 0.0,
#  'Wifi': 0.0,
#  ' Luggage dropoff allowed': 0.0,
#  ' Lock on bedroom door': 0.0,
#  ' Indoor fireplace': 0.0,
#  'Washer': 0.0,
#  ' Shower gel': 0.0,
#  ' Pack \\u2019n Play/travel crib': 0.0,
#  'Luggage dropoff allowed': 0.0,
#  ' Bathtub': 0.0,
#  ' Baking sheet': 0.0,
#  ' Paid parking off premises': 0.0,
#  ' Smart lock': 0.0,
#  'Bathtub': 0.0,
#  ' Room-darkening shades': 0.0,
#  ' Ethernet connection': 0.0,
#  ' Single level home': 0.0,
#  ' Paid parking on premises': 0.0,
#  ' Host greets you': 0.0,
#  ' Pool': 0.0,
#  ' High chair': 0.0,
#  ' Freezer': 0.0,
#  ' Children\\u2019s books and toys': 0.0,
#  'Free street parking': 0.0,
#  ' Lake access': 0.0,
#  ' Body soap': 0.0,
#  ' Breakfast': 0.0,
#  ' Hot tub': 0.0,
#  ' Portable fans': 0.0,
#  ' Private living room': 0.0,
#  ' Children\\u2019s dinnerware': 0.0,
#  ' Cleaning before checkout': 0.0,
#  ' Crib': 0.0,
#  'Kitchen': 0.0,
#  ' Barbecue utensils': 0.0,
#  'Breakfast': 0.0,
#  'Conditioner': 0.0,
#  ' Laundromat nearby': 0.0,
#  'Children\\u2019s books and toys': 0.0,
#  ' Babysitter recommendations': 0.0,
#  ' EV charger': 0.0,
#  ' Beach essentials': 0.0,
#  ' Bathroom essentials': 0.0,
#  'Hot water': 0.0,
#  ' Bedroom comforts': 0.0,
#  ' Building staff': 0.0,
#  ' Pocket wifi': 0.0,
#  ' Self check-in': 0.0,
#  ' Window guards': 0.0,
#  ' Conditioner': 0.0,
#  ' Stair gates': 0.0,
#  ' Full kitchen': 0.0,
#  'TV': 0.0,
#  ' Game console': 0.0,
#  ' Fireplace guards': 0.0,
#  ' Waterfront': 0.0,
#  'Outlet covers': 0.0,
#  ' Ceiling fan': 0.0,
#  ' Mini fridge': 0.0,
#  ' Washer \\u2013\\u00a0In unit': 0.0,
#  ' Dryer \\u2013\\u00a0In unit': 0.0,
#  ' Pour Over Coffee': 0.0,
#  ' Beachfront': 0.0,
#  'Building staff': 0.0,
#  ' Baby bath': 0.0,
#  'Lockbox': 0.0,
#  ' Changing table': 0.0,
#  ' Rice Maker': 0.0,
#  ' Trash compactor': 0.0,
#  'Hangers': 0.0,
#  ' Stainless steel oven': 0.0,
#  ' Outlet covers': 0.0,
#  ' Baby monitor': 0.0,
#  ' Nespresso machine': 0.0,
#  ' Central heating': 0.0,
#  'Long term stays allowed': 0.0,
#  ' Sound system': 0.0,
#  ' Bread maker': 0.0,
#  ' Electric stove': 0.0,
#  ' Paid parking garage off premises': 0.0,
#  'Baby bath': 0.0,
#  ' Bath & Body Works conditioner': 0.0,
#  ' Bath & Body Works body soap': 0.0,
#  ' Amazon Prime Video': 0.0,
#  ' Piano': 0.0,
#  ' Paid parking lot off premises': 0.0,
#  'Barbecue utensils': 0.0,
#  ' Central air conditioning': 0.0,
#  'Dishwasher': 0.0,
#  'Keypad': 0.0,
#  'Mini fridge': 0.0,
#  ' Pets allowed': 0.0,
#  ' Paid parking garage on premises': 0.0,
#  ' Bath & Body Works shampoo': 0.0,
#  ' Radiant heating': 0.0,
#  ' Window AC unit': 0.0,
#  ' Washer \\u2013\\u00a0In building': 0.0,
#  ' Stainless steel gas stove': 0.0,
#  'Paid parking on premises': 0.0,
#  ' Free driveway parking on premises \\u2013 1 space': 0.0,
#  ' HDTV with Netflix': 0.0,
#  ' Dryer \\u2013 In building': 0.0,
#  'Shampoo': 0.0,
#  'Hair dryer': 0.0,
#  ' Table corner guards': 0.0,
#  ' Portable air conditioning': 0.0,
#  ' Record player': 0.0,
#  ' HDTV with standard cable': 0.0,
#  ' Paid parking lot on premises': 0.0,
#  '': 0.0,
#  ' Stainless steel electric stove': 0.0,
#  'Cooking basics': 0.0,
#  ' HBO Max': 0.0,
#  'Fire extinguisher': 0.0,
#  ' Paid street parking off premises': 0.0,
#  ' Ski-in/Ski-out': 0.0,
#  'Bedroom comforts': 0.0,
#  ' Portable heater': 0.0,
#  ' Gas stove': 0.0,
#  ' Freezer has ice maker refrigerator': 0.0,
#  ' Shared hot tub': 0.0,
#  ' Wifi \\u2013 100 Mbps': 0.0,
#  'Bed linens': 0.0,
#  ' Stainless steel stove': 0.0,
#  ' 50\\ HDTV with Netflix': 0.0,
#  ' premium cable': 0.0,
#  ' Alaffia': 0.0,
#  ' Free residential garage on premises \\u2013 1 space': 0.0,
#  ' standard cable': 0.0,
#  ' Wifi \\u2013 200 Mbps': 0.0,
#  ' Kitchenette': 0.0,
#  'Bath & Body Works shampoo': 0.0,
#  ' Induction stove': 0.0,
#  ' Dove body soap': 0.0,
#  ' Natural / Vegan shampoo': 0.0,
#  ' Free driveway parking on premises \\u2013 2 spaces': 0.0,
#  ' Natural / Vegan conditioner': 0.0,
#  'Carbon monoxide alarm': 0.0,
#  ' Natural / Vegan body soap': 0.0,
#  'Smoke alarm': 0.0,
#  'Air conditioning': 0.0,
#  ' LG refrigerator': 0.0,
#  ' Free parking garage on premises \\u2013 1 space': 0.0,
#  ' TV with Netflix': 0.0,
#  ' Pantene conditioner': 0.0,
#  ' Pantene shampoo': 0.0,
#  'Oven': 0.0,
#  ' HDTV': 0.0,
#  ' 65\\ HDTV with Netflix': 0.0,
#  ' Suitable for events': 0.0,
#  ' Private hot tub': 0.0,
#  ' Wifi \\u2013 940 Mbps': 0.0,
#  ' Free wifi': 0.0,
#  ' HDTV with Amazon Prime Video': 0.0,
#  ' Wifi \\u2013 150 Mbps': 0.0,
#  ' Free parking garage on premises': 0.0,
#  ' vegan and cruelty-free conditioner': 0.0,
#  ' Free driveway parking on premises': 0.0,
#  ' Safe': 0.0,
#  ' 100% Vegan': 0.0,
#  ' 32\\ HDTV with Netflix': 0.0,
#  ' 50\\ HDTV with standard cable': 0.0,
#  ' 55\\ HDTV with Netflix': 0.0,
#  'Private entrance': 0.0,
#  'Paid parking garage off premises': 0.0,
#  'Lock on bedroom door': 0.0,
#  'Laptop-friendly workspace': 0.0,
#  'Lake access': 0.0,
#  '40\\ HDTV with Netflix': 0.0,
#  ' vegan and cruelty-free shampoo': 0.0,
#  ' Chromecast': 0.0,
#  ' vegan and cruelty-free body soap': 0.0,
#  ' Concierge': 0.0,
#  ' Dove shampoo': 0.0,
#  ' Toiletries': 0.0,
#  ' Free carport on premises \\u2013 1 space': 0.0,
#  ' Paraben': 0.0,
#  ' Paid parking garage on premises \\u2013 1 space': 0.0,
#  ' Nutresse shampoo and conditioner conditioner': 0.0,
#  ' Sulfate': 0.0,
#  ' Sub Zero refrigerator': 0.0,
#  ' Paid parking lot on premises \\u2013 1 space': 0.0,
#  ' Phosphate': 0.0,
#  ' Kitchenaid stainless steel gas stove': 0.0,
#  ' Love': 0.0,
#  ' Smart Inverter refrigerator': 0.0,
#  ' Bed sheets and pillows': 0.0,
#  'Dacor duel fuel - gas stove top': 0.0,
#  ' Beauty and Planet 2 in 1 Shampoo and Conditioner Bar (Coconut and Mimosa) shampoo': 0.0,
#  ' Beauty and Planet 2 in 1 Shampoo and Conditioner Bar (Coconut and Mimosa) conditioner': 0.0,
#  'Elevator': 0.0,
#  'Ginger Lily Farms Club & Fitness Aloe Vera Moisturizing Conditioner': 0.0,
#  'Essentials': 0.0,
#  ' Slippers': 0.0,
#  ' Bertazzoni electric oven oven': 0.0,
#  'Kitchenaid stainless steel oven': 0.0,
#  ' Paid parking on premises \\u2013 1 space': 0.0,
#  'Laundromat nearby': 0.0,
#  ' Panasonic sound system': 0.0,
#  'Nutresse shampoo shampoo': 0.0,
#  ' Bertazzoni - gas top gas stove': 0.0,
#  ' Kitchen Aide refrigerator': 0.0,
#  ' Bike rental available': 0.0,
#  ' Bluetooth sound system': 0.0,
#  ' Onsite restaurant \\u2014 Cosmica': 0.0,
#  ' Outdoor Grill gas stove': 0.0,
#  ' viking stainless steel oven': 0.0,
#  ' Sound system with aux': 0.0,
#  ' Sonos sound system': 0.0,
#  'Alba or Pantene conditioner': 0.0,
#  'BOSCH stainless steel gas stove': 0.0,
#  ' Sonos Bluetooth sound system': 0.0,
#  ' Softens': 0.0,
#  'Bed sheets and pillows': 0.0,
#  ' Breck conditioner': 0.0,
#  ' Smoking allowed': 0.0,
#  ' Bose Bluetooth sound system': 0.0,
#  ' Bosch stainless steel gas stove': 0.0,
#  ' Bosch': 0.0,
#  'Children\\u2019s dinnerware': 0.0,
#  ' Bluetooth speaker': 0.0,
#  ' Blomberg refrigerator': 0.0,
#  ' Self-parking \\u2014 $42/stay': 0.0,
#  ' Complimentary breakfast': 0.0,
#  ' Samsung oven': 0.0,
#  ' 40\\ HDTV with Amazon Prime Video': 0.0,
#  ' 40\\ HDTV': 0.0,
#  ' 39\\ HDTV with Netflix': 0.0,
#  ' 365 Whole Foods Shampoo shampoo': 0.0,
#  ' 365 Whole Foods Conditioner conditioner': 0.0,
#  ' 34\\ TV with standard cable': 0.0,
#  ' 32\\ TV with Netflix': 0.0,
#  ' 32\\ TV': 0.0,
#  ' 32\\ HDTV': 0.0,
#  ' 43\\ TV': 0.0,
#  ' 3/4 size fridge + mini fridge': 0.0,
#  ' 27\\ TV': 0.0,
#  ' 24-hour fitness center': 0.0,
#  ' 20\\ HDTV': 0.0,
#  ' 2 burner Cook Top Only electric stove': 0.0,
#  ' 100% Vegan and Cruelty-Free body soap': 0.0,
#  ' Samsung Soundbar M5 sound system with Bluetooth and aux': 0.0,
#  '  Bath & Body Works shampoo': 0.0,
#  ' 40\\ HDTV with Netflix': 0.0,
#  ' 48\\ HDTV with Netflix': 0.0,
#  ' BOSCH stainless steel oven': 0.0,
#  'Stainless steel oven': 0.0,
#  ' BOSCH refrigerator': 0.0,
#  ' Selection of travel size provided conditioner': 0.0,
#  ' Apartment-sized refrigerator and freezer refrigerator': 0.0,
#  ' American Range stainless steel oven': 0.0,
#  ' American Range stainless steel gas stove': 0.0,
#  ' Alexa sound system': 0.0,
#  ' Alexa and on tv sound system': 0.0,
#  ' Samsung stainless steel oven': 0.0,
#  ' Samsung stainless steel gas stove': 0.0,
#  ' Samsung refrigerator': 0.0,
#  ' 60\\ TV with Chromecast': 0.0,
#  ' 55\\ TV with standard cable': 0.0,
#  ' 55\\ TV with Netflix': 0.0,
#  ' Polk sound bar can be accessed via your wifi/phone sound system': 0.0,
#  ' 55\\ HDTV': 0.0,
#  ' 50\\ TV with Chromecast': 0.0,
#  ' 50\\ TV': 0.0,
#  ' Samsung stainless steel electric stove': 0.0,
#  ' Nourishes and Cleans Skin': 0.0,
#  ' Convection  oven': 0.0,
#  ' No stove but has a hot plate electric stove': 0.0,
#  ' Gas stove stainless steel gas stove': 0.0,
#  ' Gluten and Cruelty-Free shampoo': 0.0,
#  ' Gluten & Cruelty-Free conditioner': 0.0,
#  ' Ginger Lily Farms Botanicals Island Tranquility Nourishing Body Wash': 0.0,
#  ' Ginger Lily Farms Botanicals Coco Mango Moisturizing Shampoo': 0.0,
#  ' Gilchrist and Somes body soap': 0.0,
#  ' General Electric refrigerator': 0.0,
#  ' General Electric oven': 0.0,
#  ' General Electric electric stove': 0.0,
#  ' TV with Chromecast': 0.0,
#  ' HAIER 4 DOOR with Digital Display (lock': 0.0,
#  ' Wifi \\u2013 363 Mbps': 0.0,
#  ' Game room': 0.0,
#  ' Wifi \\u2013 60 Mbps': 0.0,
#  ' GE refrigerator': 0.0,
#  ' GE WIFI Double oven stainless steel oven': 0.0,
#  ' GE 5 Burner stove  stainless steel gas stove': 0.0,
#  ' Wifi \\u2013 600 Mbps': 0.0,
#  ' Frigidaire stainless steel electric stove': 0.0,
#  ' LG oven': 0.0,
#  ' LG gas stove': 0.0,
#  ' variety conditioner': 0.0,
#  ' Varies body soap': 0.0,
#  " Trader Joe's Tea Tree shampoo": 0.0,
#  ' Irish Spring Shower gel/Dial liquid hand soap/Tulip body soap body soap': 0.0,
#  ' KitchenAid stainless steel oven': 0.0,
#  " Trader Joe's Tea Tree shower gel and selection of bar soaps body soap": 0.0,
#  " If Dominic goes shopping it's likely a name brand like Ivory": 0.0,
#  " I'm not sure of brand": 0.0,
#  ' House bikes': 0.0,
#  ' Usually Palmolive bar soap and Soft Soap pump in addition to shower gel. body soap': 0.0,
#  ' Varies conditioner': 0.0,
#  " L'occitane bar soap": 0.0,
#  ' High end hot plate; large size convection toaster oven induction stove': 0.0,
#  ' Viking stainless steel gas stove': 0.0,
#  ' Whole Foods Grapefruit body soap': 0.0,
#  ' Whole Foods Grapefruit conditioner': 0.0,
#  ' Kitchenaid refrigerator': 0.0,
#  ' Wifi \\u2013 15 Mbps': 0.0,
#  ' HDTV with premium cable': 0.0,
#  ' Kitchenaid stainless steel oven': 0.0,
#  ' Frigidaire refrigerator': 0.0,
#  ' Summit refrigerator': 0.0,
#  ' Wifi \\u2013 70 Mbps': 0.0,
#  ' Dove or Pantene conditioner': 0.0,
#  " if I go shopping it's a bit more bougie. Enjoy the element of surprise while staying at our home! body soap": 0.0,
#  ' if needed refrigerator': 0.0,
#  ' liquid body soap': 0.0,
#  ' Dr. Teals body soap': 0.0,
#  ' Dr. Bronners body soap': 0.0,
#  " Dr Bonner's  shampoo": 0.0,
#  ' Stainless steel induction stove': 0.0,
#  ' Dove or Pantene shampoo': 0.0,
#  ' Dove conditioner': 0.0,
#  ' Wifi \\u2013 90 Mbps': 0.0,
#  ' Natural Spa Quality': 0.0,
#  ' Stainless fridge/freezer refrigerator': 0.0,
#  ' New.  It  four burners very good full size stove and full oven. It is white. electric stove': 0.0,
#  ' Danby refrigerator': 0.0,
#  ' Dacor duel fuel stove - electric oven': 0.0,
#  ' thermostat': 0.0,
#  ' variety body soap': 0.0,
#  ' KitchenAid refrigerator': 0.0,
#  ' gas stove top oven': 0.0,
#  ' Eco body soap': 0.0,
#  ' etc.) refrigerator': 0.0,
#  ' Electrolux refrigerator': 0.0,
#  ' Laundry services': 0.0,
#  ' Limited housekeeping \\u2014 ': 0.0,
#  ' Little Seed Farm sustainable handcrafted bar soap (zero waste!) body soap': 0.0,
#  ' Sub zero refrigerator': 0.0,
#  ' Wifi \\u2013 980 Mbps': 0.0,
#  ' Loreal conditioner': 0.0,
#  ' Free carport on premises': 0.0,
#  ' Fisher and Paykel stainless steel oven': 0.0,
#  ' Fisher and Paykel stainless steel gas stove': 0.0,
#  ' Fisher Paykel stainless steel gas stove': 0.0,
#  ' and Jayson body wash body soap': 0.0,
#  ' and because it is in the Studio I bought a self defrost because this keeps the room much quieter!  It has the freezer in the refrigerator. refrigerator': 0.0,
#  ' body wash body soap': 0.0,
#  ' but I bought new some years ago. It is older but has always worked very good': 0.0,
#  ' clock radio sound system with Bluetooth and aux': 0.0,
#  ' double ovens stainless steel oven': 0.0,
#  ' electric oven gas stove': 0.0,
#  'Wifi \\u2013 60 Mbps': 0.0}

# %%
i = 1
for item in numeric_columns:
    plt.subplot(2,2, i)
    graph = air_listings[item].plot(kind='bar', subplots = True)
    i += 1
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-290-4e3ee8cd1972> in <module>
#       2 for item in numeric_columns:
#       3     plt.subplot(2,2, i)
# ----> 4     graph = air_listings[item].plot(kind='bar', subplots = True)
#       5     i += 1
#       6     plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
airtest = air_calendar.groupby([ 'city'])[['date', 'listing_id','available']]
airtest.head()
# Out:
#         date  listing_id  available
# 0 2020-10-25    22153582          1
# 1 2020-10-26    22153582          1
# 2 2020-10-27    22153582          1
# 3 2020-10-28    22153582          1
# 4 2020-10-29    22153582          1
# 0 2020-11-10        3781          0
# 1 2020-11-10     3677662          0
# 2 2020-11-11     3677662          0
# 3 2020-11-12     3677662          1
# 4 2020-11-13     3677662          1

# %%
top_rated_boston = air_listings[air_listings['city']== 'Boston']
top_rated_seattle = air_listings[air_listings['city'] == 'Seattle']

# %%
top_rating_neighborhood_b = top_rated_boston.groupby(top_rated_boston['neighbourhood_cleansed'])['review_scores_location'].mean()
top_rating_neighborhood_b[:10].sort_values(ascending=False).plot(kind='bar')
plt.title("Highest Rated Neighborhoods in Boston")
plt.xlabel('Neighborhood')
plt.ylabel('Rating')
plt.show()

# %%
top_rating_neighborhood_s = top_rated_seattle.groupby(top_rated_seattle['neighbourhood_cleansed'])['review_scores_location'].mean()
top_rating_neighborhood_s[:10].sort_values(ascending=False).plot(kind='bar')
plt.title("Highest Rated Neighborhoods in Seattle")
plt.xlabel('Neighborhood')
plt.ylabel('Rating')
plt.show()

# %%
top_rating_neighborhood_s.sort_values(ascending=False).tail(10)

# %%
mean_price_neighborhood_s = top_rated_seattle.groupby(top_rated_seattle['neighbourhood_cleansed'])['price'].mean()
round(mean_price_neighborhood_s[:10].sort_values(ascending=False), 2)

# %%
mean_price_neighborhood_b = top_rated_boston.groupby(top_rated_seattle['neighbourhood_cleansed'])['price'].mean()
round(mean_price_neighborhood_b[:10].sort_values(ascending=False), 2)

# %%
air_reviews.info()

# %%
airbnb_seattle_reviews.hist();

# %%
airbnb_seattle_calendar.hist();

# %%
airbnb_seattle_listings.hist();

# %%
sns.heatmap(airbnb_seattle_listings.corr(), annot=True, fmt = '.2f');

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# In this section, we need to alter create dummy variables for the amenities and host_verification columns.

# %%
air_listings.amenities.head()
# Out:
# 0    ["Children\u2019...
# 1    ["Iron", "Hanger...
# 2    ["Iron", "TV", "...
# 3    ["Conditioner", ...
# 4    ["Iron", "TV", "...
# Name: amenities, dtype: object

# %%
air_listings.host_verifications.head()
# Out:
# 0    ['email', 'phone...
# 1    ['email', 'phone...
# 2    ['email', 'phone...
# 3    ['email', 'phone...
# 4    ['email', 'phone...
# Name: host_verifications, dtype: object

# %%
# This function cleans the amenities and puts them into a list

def get_column_name_list(column, variable_name):
    
    col_list=[]
    for col in column:
        col=col.replace('"','')
        col=col.replace('{','')
        col=col.replace('}','')
        col=col.replace('[','')
        col=col.replace(']','')        
        col=col.replace("translation missing: en.hosting_amenity_49", 'Unknown amenity')
        col=col.replace("translation missing: en.hosting_amenity_50", 'Unknown amenity')
        col_list += col.split(',')

    #Transform list into a data frame
    col_list2=pd.DataFrame(col_list) 
    
    #rename the column as variable_name
    col_list2.rename(columns={0:variable_name},inplace=True) 

    #group by category and count
    col_list2=col_list2.groupby(variable_name)[variable_name].count().sort_values(ascending=False)
    
    #Rename varible_name column as count
    col_list2.rename({variable_name:'count'},inplace=True) 

    return col_list2

# %%
#Get amenities

amenities=get_column_name_list(air_listings.amenities, 'amenities') #Total



amenities

amenities/amenities.sum()*100 #Percentage of total tags

(amenities[0:35]/amenities.sum()*100).sum()

amenities
# Out:
# amenities
#  Smoke alarm                                                                     7373
#  Essentials                                                                      7061
#  Carbon monoxide alarm                                                           6899
#  Heating                                                                         6894
#  Hangers                                                                         6783
#                                                                                  ...
#  but I bought new some years ago. It is older but has always worked very good       1
#  clock radio sound system with Bluetooth and aux                                    1
#  double ovens stainless steel oven                                                  1
#  electric oven gas stove                                                            1
# Wifi \u2013 60 Mbps                                                                 1
# Name: amenities, Length: 393, dtype: int64

# %%
unique_items = amenities

# %%
def boolean_df(item_lists, unique_items):
    
    #create empty dictionary
    bool_dict={}
    
    #loop through all the tags
    for i, item in enumerate(unique_items):
        
        # apply boolean mask
        bool_dict[item] = item_lists.apply(lambda x: item in x)
    
    # return the results as a dataframe
    return pd.DataFrame(bool_dict)

# %%
dummymatrix = boolean_df(listings['amenities'], unique_items.keys())
collist = dummymatrix.columns.values
collist
# Out:
# array([' Smoke alarm', ' Essentials', ' Carbon monoxide alarm',
#        ' Heating', ' Hangers', ' Hair dryer', ' Kitchen', ' Shampoo',
#        ' Wifi', ' TV', ' Laptop-friendly workspace', ' Dryer',
#        ' Hot water', ' Refrigerator', ' Microwave', ' Coffee maker',
#        ' Dishes and silverware', ' Fire extinguisher', ' Washer', ' Iron',
#        ' Cooking basics', ' Bed linens', ' Stove', ' Oven',
#        ' Air conditioning', ' Long term stays allowed',
#        ' Private entrance', ' Extra pillows and blankets',
#        ' First aid kit', ' Dishwasher', ' Free street parking',
#        ' Free parking on premises', ' Patio or balcony', ' Cable TV',
#        ' Garden or backyard', 'Iron', ' Keypad', ' Elevator', ' Gym',
#        ' BBQ grill', ' Lockbox', 'Wifi', ' Luggage dropoff allowed',
#        ' Lock on bedroom door', ' Indoor fireplace', 'Washer',
#        ' Shower gel', ' Pack \\u2019n Play/travel crib',
#        'Luggage dropoff allowed', ' Bathtub', ' Baking sheet',
#        ' Paid parking off premises', ' Smart lock', 'Bathtub',
#        ' Room-darkening shades', ' Ethernet connection',
#        ' Single level home', ' Paid parking on premises',
#        ' Host greets you', ' Pool', ' High chair', ' Freezer',
#        ' Children\\u2019s books and toys', 'Free street parking',
#        ' Lake access', ' Body soap', ' Breakfast', ' Hot tub',
#        ' Portable fans', ' Private living room',
#        ' Children\\u2019s dinnerware', ' Cleaning before checkout',
#        ' Crib', 'Kitchen', ' Barbecue utensils', 'Breakfast',
#        'Conditioner', ' Laundromat nearby',
#        'Children\\u2019s books and toys', ' Babysitter recommendations',
#        ' EV charger', ' Beach essentials', ' Bathroom essentials',
#        'Hot water', ' Bedroom comforts', ' Building staff',
#        ' Pocket wifi', ' Self check-in', ' Window guards', ' Conditioner',
#        ' Stair gates', ' Full kitchen', 'TV', ' Game console',
#        ' Fireplace guards', ' Waterfront', 'Outlet covers',
#        ' Ceiling fan', ' Mini fridge', ' Washer \\u2013\\u00a0In unit',
#        ' Dryer \\u2013\\u00a0In unit', ' Pour Over Coffee', ' Beachfront',
#        'Building staff', ' Baby bath', 'Lockbox', ' Changing table',
#        ' Rice Maker', ' Trash compactor', 'Hangers',
#        ' Stainless steel oven', ' Outlet covers', ' Baby monitor',
#        ' Nespresso machine', ' Central heating',
#        'Long term stays allowed', ' Sound system', ' Bread maker',
#        ' Electric stove', ' Paid parking garage off premises',
#        'Baby bath', ' Bath & Body Works conditioner',
#        ' Bath & Body Works body soap', ' Amazon Prime Video', ' Piano',
#        ' Paid parking lot off premises', 'Barbecue utensils',
#        ' Central air conditioning', 'Dishwasher', 'Keypad', 'Mini fridge',
#        ' Pets allowed', ' Paid parking garage on premises',
#        ' Bath & Body Works shampoo', ' Radiant heating',
#        ' Window AC unit', ' Washer \\u2013\\u00a0In building',
#        ' Stainless steel gas stove', 'Paid parking on premises',
#        ' Free driveway parking on premises \\u2013 1 space',
#        ' HDTV with Netflix', ' Dryer \\u2013 In building', 'Shampoo',
#        'Hair dryer', ' Table corner guards', ' Portable air conditioning',
#        ' Record player', ' HDTV with standard cable',
#        ' Paid parking lot on premises', '',
#        ' Stainless steel electric stove', 'Cooking basics', ' HBO Max',
#        'Fire extinguisher', ' Paid street parking off premises',
#        ' Ski-in/Ski-out', 'Bedroom comforts', ' Portable heater',
#        ' Gas stove', ' Freezer has ice maker refrigerator',
#        ' Shared hot tub', ' Wifi \\u2013 100 Mbps', 'Bed linens',
#        ' Stainless steel stove', ' 50\\ HDTV with Netflix',
#        ' premium cable', ' Alaffia',
#        ' Free residential garage on premises \\u2013 1 space',
#        ' standard cable', ' Wifi \\u2013 200 Mbps', ' Kitchenette',
#        'Bath & Body Works shampoo', ' Induction stove', ' Dove body soap',
#        ' Natural / Vegan shampoo',
#        ' Free driveway parking on premises \\u2013 2 spaces',
#        ' Natural / Vegan conditioner', 'Carbon monoxide alarm',
#        ' Natural / Vegan body soap', 'Smoke alarm', 'Air conditioning',
#        ' LG refrigerator',
#        ' Free parking garage on premises \\u2013 1 space',
#        ' TV with Netflix', ' Pantene conditioner', ' Pantene shampoo',
#        'Oven', ' HDTV', ' 65\\ HDTV with Netflix', ' Suitable for events',
#        ' Private hot tub', ' Wifi \\u2013 940 Mbps', ' Free wifi',
#        ' HDTV with Amazon Prime Video', ' Wifi \\u2013 150 Mbps',
#        ' Free parking garage on premises',
#        ' vegan and cruelty-free conditioner',
#        ' Free driveway parking on premises', ' Safe', ' 100% Vegan',
#        ' 32\\ HDTV with Netflix', ' 50\\ HDTV with standard cable',
#        ' 55\\ HDTV with Netflix', 'Private entrance',
#        'Paid parking garage off premises', 'Lock on bedroom door',
#        'Laptop-friendly workspace', 'Lake access',
#        '40\\ HDTV with Netflix', ' vegan and cruelty-free shampoo',
#        ' Chromecast', ' vegan and cruelty-free body soap', ' Concierge',
#        ' Dove shampoo', ' Toiletries',
#        ' Free carport on premises \\u2013 1 space', ' Paraben',
#        ' Paid parking garage on premises \\u2013 1 space',
#        ' Nutresse shampoo and conditioner conditioner', ' Sulfate',
#        ' Sub Zero refrigerator',
#        ' Paid parking lot on premises \\u2013 1 space', ' Phosphate',
#        ' Kitchenaid stainless steel gas stove', ' Love',
#        ' Smart Inverter refrigerator', ' Bed sheets and pillows',
#        'Dacor duel fuel - gas stove top',
#        ' Beauty and Planet 2 in 1 Shampoo and Conditioner Bar (Coconut and Mimosa) shampoo',
#        ' Beauty and Planet 2 in 1 Shampoo and Conditioner Bar (Coconut and Mimosa) conditioner',
#        'Elevator',
#        'Ginger Lily Farms Club & Fitness Aloe Vera Moisturizing Conditioner',
#        'Essentials', ' Slippers', ' Bertazzoni electric oven oven',
#        'Kitchenaid stainless steel oven',
#        ' Paid parking on premises \\u2013 1 space', 'Laundromat nearby',
#        ' Panasonic sound system', 'Nutresse shampoo shampoo',
#        ' Bertazzoni - gas top gas stove', ' Kitchen Aide refrigerator',
#        ' Bike rental available', ' Bluetooth sound system',
#        ' Onsite restaurant \\u2014 Cosmica', ' Outdoor Grill gas stove',
#        ' viking stainless steel oven', ' Sound system with aux',
#        ' Sonos sound system', 'Alba or Pantene conditioner',
#        'BOSCH stainless steel gas stove', ' Sonos Bluetooth sound system',
#        ' Softens', 'Bed sheets and pillows', ' Breck conditioner',
#        ' Smoking allowed', ' Bose Bluetooth sound system',
#        ' Bosch stainless steel gas stove', ' Bosch',
#        'Children\\u2019s dinnerware', ' Bluetooth speaker',
#        ' Blomberg refrigerator', ' Self-parking \\u2014 $42/stay',
#        ' Complimentary breakfast', ' Samsung oven',
#        ' 40\\ HDTV with Amazon Prime Video', ' 40\\ HDTV',
#        ' 39\\ HDTV with Netflix', ' 365 Whole Foods Shampoo shampoo',
#        ' 365 Whole Foods Conditioner conditioner',
#        ' 34\\ TV with standard cable', ' 32\\ TV with Netflix',
#        ' 32\\ TV', ' 32\\ HDTV', ' 43\\ TV',
#        ' 3/4 size fridge + mini fridge', ' 27\\ TV',
#        ' 24-hour fitness center', ' 20\\ HDTV',
#        ' 2 burner Cook Top Only electric stove',
#        ' 100% Vegan and Cruelty-Free body soap',
#        ' Samsung Soundbar M5 sound system with Bluetooth and aux',
#        '  Bath & Body Works shampoo', ' 40\\ HDTV with Netflix',
#        ' 48\\ HDTV with Netflix', ' BOSCH stainless steel oven',
#        'Stainless steel oven', ' BOSCH refrigerator',
#        ' Selection of travel size provided conditioner',
#        ' Apartment-sized refrigerator and freezer refrigerator',
#        ' American Range stainless steel oven',
#        ' American Range stainless steel gas stove', ' Alexa sound system',
#        ' Alexa and on tv sound system', ' Samsung stainless steel oven',
#        ' Samsung stainless steel gas stove', ' Samsung refrigerator',
#        ' 60\\ TV with Chromecast', ' 55\\ TV with standard cable',
#        ' 55\\ TV with Netflix',
#        ' Polk sound bar can be accessed via your wifi/phone sound system',
#        ' 55\\ HDTV', ' 50\\ TV with Chromecast', ' 50\\ TV',
#        ' Samsung stainless steel electric stove',
#        ' Nourishes and Cleans Skin', ' Convection  oven',
#        ' No stove but has a hot plate electric stove',
#        ' Gas stove stainless steel gas stove',
#        ' Gluten and Cruelty-Free shampoo',
#        ' Gluten & Cruelty-Free conditioner',
#        ' Ginger Lily Farms Botanicals Island Tranquility Nourishing Body Wash',
#        ' Ginger Lily Farms Botanicals Coco Mango Moisturizing Shampoo',
#        ' Gilchrist and Somes body soap', ' General Electric refrigerator',
#        ' General Electric oven', ' General Electric electric stove',
#        ' TV with Chromecast', ' HAIER 4 DOOR with Digital Display (lock',
#        ' Wifi \\u2013 363 Mbps', ' Game room', ' Wifi \\u2013 60 Mbps',
#        ' GE refrigerator', ' GE WIFI Double oven stainless steel oven',
#        ' GE 5 Burner stove  stainless steel gas stove',
#        ' Wifi \\u2013 600 Mbps',
#        ' Frigidaire stainless steel electric stove', ' LG oven',
#        ' LG gas stove', ' variety conditioner', ' Varies body soap',
#        " Trader Joe's Tea Tree shampoo",
#        ' Irish Spring Shower gel/Dial liquid hand soap/Tulip body soap body soap',
#        ' KitchenAid stainless steel oven',
#        " Trader Joe's Tea Tree shower gel and selection of bar soaps body soap",
#        " If Dominic goes shopping it's likely a name brand like Ivory",
#        " I'm not sure of brand", ' House bikes',
#        ' Usually Palmolive bar soap and Soft Soap pump in addition to shower gel. body soap',
#        ' Varies conditioner', " L'occitane bar soap",
#        ' High end hot plate; large size convection toaster oven induction stove',
#        ' Viking stainless steel gas stove',
#        ' Whole Foods Grapefruit body soap',
#        ' Whole Foods Grapefruit conditioner', ' Kitchenaid refrigerator',
#        ' Wifi \\u2013 15 Mbps', ' HDTV with premium cable',
#        ' Kitchenaid stainless steel oven', ' Frigidaire refrigerator',
#        ' Summit refrigerator', ' Wifi \\u2013 70 Mbps',
#        ' Dove or Pantene conditioner',
#        " if I go shopping it's a bit more bougie. Enjoy the element of surprise while staying at our home! body soap",
#        ' if needed refrigerator', ' liquid body soap',
#        ' Dr. Teals body soap', ' Dr. Bronners body soap',
#        " Dr Bonner's  shampoo", ' Stainless steel induction stove',
#        ' Dove or Pantene shampoo', ' Dove conditioner',
#        ' Wifi \\u2013 90 Mbps', ' Natural Spa Quality',
#        ' Stainless fridge/freezer refrigerator',
#        ' New.  It  four burners very good full size stove and full oven. It is white. electric stove',
#        ' Danby refrigerator', ' Dacor duel fuel stove - electric oven',
#        ' thermostat', ' variety body soap', ' KitchenAid refrigerator',
#        ' gas stove top oven', ' Eco body soap', ' etc.) refrigerator',
#        ' Electrolux refrigerator', ' Laundry services',
#        ' Limited housekeeping \\u2014 ',
#        ' Little Seed Farm sustainable handcrafted bar soap (zero waste!) body soap',
#        ' Sub zero refrigerator', ' Wifi \\u2013 980 Mbps',
#        ' Loreal conditioner', ' Free carport on premises',
#        ' Fisher and Paykel stainless steel oven',
#        ' Fisher and Paykel stainless steel gas stove',
#        ' Fisher Paykel stainless steel gas stove',
#        ' and Jayson body wash body soap',
#        ' and because it is in the Studio I bought a self defrost because this keeps the room much quieter!  It has the freezer in the refrigerator. refrigerator',
#        ' body wash body soap',
#        ' but I bought new some years ago. It is older but has always worked very good',
#        ' clock radio sound system with Bluetooth and aux',
#        ' double ovens stainless steel oven', ' electric oven gas stove',
#        'Wifi \\u2013 60 Mbps'], dtype=object)

# %%
amenities_list = {"  Bath & Body Works shampoo" : "Shampoo",  " 100% Vegan and Cruelty-Free body soap" : "Soap",
" 100% Vegan" : "Vegan", " 2 burner Cook Top Only electric stove" : "Stove",
" 24-hour fitness center" : "24 hour fitness center", " 20\\ HDTV" : "TV",
" 3/4 size fridge + mini fridge" : "Refrigerator", " 27\\ TV" : "TV",
" 32\\ HDTV with Netflix" : "TV with Netflix", " 32\\ HDTV" : "TV with Netflix",
" 32\\ TV with Netflix" : "TV with Netflix", " 32\\ TV" : "TV", 
" 34\\ TV with standard cable" : "TV with Cable", " 365 Whole Foods Conditioner conditioner" : "Conditioner",
" 365 Whole Foods Shampoo shampoo" : "Shampoo", " 39\\ HDTV with Netflix" : "TV with Netflix",
" 40\\ HDTV with Amazon Prime Video": "TV with Amazon Prime", " 40\\ HDTV with Netflix" : "TV with Netflix",
" 40\\ HDTV" : "TV",  " 43\\ TV" : "TV",  " 48\\ HDTV with Netflix" : "TV",
 " 50\\ HDTV with Netflix" : "TV with Netflix",
" 50\\ HDTV with standard cable" : "TV with Cable", " 50\\ TV with Chromecast" : "TV with Cromecast", 
" 50\\ TV" : "TV",        " 55\\ HDTV with Netflix": "TV with Netflix",  " 55\\ HDTV" : "TV", 
" 55\\ TV with Netflix" : "TV with Netflix",  " 55\\ TV with standard cable" : "TV with Cable",
" 60\\ TV with Chromecast": "TV with Cromecast",  " 65\\ HDTV with Netflix" : "TV with Netflix", 
 " Air conditioning" : "Air Cond",  " Alaffia" : "Other",        " Alexa and on tv sound system" : "Alexa sound system",  " Alexa sound system" : "Alexa sound system", " Amazon Prime Video": "TV with Amazon Prime", 
" American Range stainless steel gas stove" : "Stove",  " American Range stainless steel oven" : "Oven",
" and because it is in the Studio I bought a self defrost because this keeps the room much quieter!  It has the freezer in the refrigerator. refrigerator": "Other",   " and Jayson body wash body soap" : "Body wash",
" Apartment-sized refrigerator and freezer refrigerator" : "Refrigerator",  " Baby bath" : "Bassinet",
 "Lockbox" : "Lockbox", " Baby monitor" : "Baby monitor",  " Babysitter recommendations" : "Other",
" Barbecue utensils" : "Kitchenware",  " Bath & Body Works body soap" : "Soap", 
" Bath & Body Works conditioner" : "Conditioner",  " Bath & Body Works shampoo" : "Shampoo",
" Bathroom essentials" : "Essentials",  " Bathtub" : "Bathtub", " Baking sheet" : "Kitchenware",
 " BBQ grill": "BBQ grill",  " Beach essentials" : "Beach essentials", " Beachfront" : "Beachfront",
 " Beauty and Planet 2 in 1 Shampoo and Conditioner Bar (Coconut and Mimosa) shampoo" : "Shampoo",
" Beauty and Planet 2 in 1 Shampoo and Conditioner Bar (Coconut and Mimosa) conditioner" : "Shampoo",  " Bed linens": "Linens",  " Bed sheets and pillows" : "Bed sheets and pillows",
" Bedroom comforts" : "Bed sheets and pillows",  " Bertazzoni - gas top gas stove" : "Stove", 
 " Bertazzoni electric oven oven" : "Oven", " Bike rental available" : "Bike rental" , 
" Blomberg refrigerator" : "Refrigerator", " Bluetooth sound system" : "Bluetooth sound system",
" Bluetooth speaker" : "Bluetooth speaker",  " Body soap" : "Body wash",  " body wash body soap" : "Body wash",
" BOSCH refrigerator" : "Refrigerator",  " Bosch stainless steel gas stove" : "Stove",
" BOSCH stainless steel oven" : "Oven", " Bosch" : "Oven", " Bose Bluetooth sound system" : "Bluetooth sound system", " Bread maker" : "Bread maker",  " Breakfast" : "Breakfast",  " Breck conditioner" : "Conditioner",  " Building staff" : "On-premise staff",
       " but I bought new some years ago. It is older but has always worked very good" : "Other",
" Cable TV": "Cable TV", " Carbon monoxide alarm" : "Carbon monoxide alarm",
" Ceiling fan" : "Ceiling fan", " Central air conditioning" : "Central air",  " Central heating" : "Central heating",
 " Changing table" : "Changing table", " Children\\u2019s books and toys" : "Childrens books and toys",
  " Children\\u2019s dinnerware" : "Children dinnerware", " Chromecast" : "TV with Chromecast",
 " Cleaning before checkout" : "Other", " clock radio sound system with Bluetooth and aux" : "Bluetooth sound system", " Coffee maker": "Coffee Maker",  " Complimentary breakfast" : "Complimentary breakfast",
 " Concierge" : "Concierge",  " Conditioner" : "Conditioner",  " Convection  oven" : "Oven",
" Cooking basics" : "Cookware", " Crib" : "Crib", " Dacor duel fuel stove - electric oven" : "Oven",
" Danby refrigerator" : "Refrigerator",  " Dishes and silverware" : "Dinnerware",
" Dishwasher" : "Dishwasher", " double ovens stainless steel oven" : "Oven",
 " electric oven gas stove" : "Stove",  " Dove body soap" : "Soap",  " Dove conditioner" : "Conditioner",
" Dove or Pantene conditioner" : "Conditioner",  " Dove or Pantene shampoo" : "Shampoo",
" Dove shampoo" : "Shampoo", " Dr. Bronners body soap" : "Soap", " Dr. Teals body soap" : "Soap",
" Dryer" : "Dryer", " Dryer \\u2013 In building" : "Dryer",  "Shampoo": "Shampoo",
" Dryer \\u2013\\u00a0In unit" : "Dryer",   " Eco body soap" : "Soap",
 " etc.) refrigerator" : "Refrigerator", " Electric stove" : "Stove",
" Electrolux refrigerator" : " Refrigerator", " Elevator": "Elevator",  " Essentials" : "Essentials",
 " Ethernet connection" : "Ethernet connection", " EV charger" : "EV charger",
" Extra pillows and blankets": "Extra pillows and blankets", " Fireplace guards" : "Fireplace guards", 
 " First aid kit" : "First aid kit", " Fisher and Paykel stainless steel gas stove" : "Stove",
" Fisher and Paykel stainless steel oven" : "Oven", " Fisher Paykel stainless steel gas stove" : "Stove",
" Free carport on premises \\u2013 1 space" : "Free parking on premises",
 " Free carport on premises" : "Free parking on premises",
" Free driveway parking on premises \\u2013 1 space" : "Free parking on premises",
" Free driveway parking on premises \\u2013 2 spaces" : "Free parking on premises",
" Free driveway parking on premises" : "Free parking on premises",
" Free parking garage on premises \\u2013 1 space" : "Free parking on premises",
" Free parking garage on premises" : "Free parking on premises",
" Free parking on premises" : "Free parking on premises",
" Free residential garage on premises \\u2013 1 space" : "Free parking on premises",
 " Free street parking": "Free street parking",   " Free wifi" : "Wifi",
 " Freezer has ice maker refrigerator" : "Refrigerator", " Freezer" : "Freezer",
 " Frigidaire refrigerator" : "Refrigerator", " Frigidaire stainless steel electric stove" : "Stove",
 " Full kitchen" : "Kitchen",  " Game console" : "Game console",  " Garden or backyard": "Garden or backyard", 
" Gas stove stainless steel gas stove" : "Stove", " gas stove top oven" : "Stove", " Gas stove" : "Stove",
  " GE 5 Burner stove  stainless steel gas stove" : "Stove" , " GE refrigerator" : "Refrigerator",
 " GE WIFI Double oven stainless steel oven" : "Oven",  " General Electric electric stove" : "Stove",
" General Electric oven" : "Oven",  " General Electric refrigerator" : "Refrigerator",
" Gilchrist and Somes body soap" : "Soap",
 " Ginger Lily Farms Botanicals Coco Mango Moisturizing Shampoo" : "Shampoo",
" Ginger Lily Farms Botanicals Island Tranquility Nourishing Body Wash" : "Body wash",
 " Gluten & Cruelty-Free conditioner" : "Conditioner", " Gluten and Cruelty-Free shampoo" : "Shampoo",
 " Gym": "Gym", " HAIER 4 DOOR with Digital Display (lock" : "Smart lock",
 " Hair dryer" : "Hair dryer", " Hangers": "Hangers",  " HBO Max" : "TV with HBO Max",
" HDTV with Amazon Prime Video" : "TV with Amazon Prime", " HDTV with Netflix" : "TV with Netflix", 
 " HDTV with standard cable" : "TV with Cable",  " HDTV" : "TV",  " Heating" : "Heating",
" High end hot plate; large size convection toaster oven induction stove" : "Stove",
" Host greets you" : "Host greeting",  " Hot tub" : "Hot tub", " Hot water" : "Hot Water",
 " House bikes" : "Free bicycles", " if needed refrigerator" : "Refrigerator",
" Indoor fireplace": "Indoor fireplace",  " Induction stove" : "Stove",
" Irish Spring Shower gel/Dial liquid hand soap/Tulip body soap body soap" : "Shower gel",
 " Iron": "Iron",  " Keypad": "Keyless entry",  " Kitchen" : "Kitchen", " Kitchen Aide refrigerator" : "Refrigerator",
 " Kitchenaid refrigerator" : "Refrigerator",  " KitchenAid refrigerator" : "Refrigerator",
" Kitchenaid stainless steel gas stove" : "Stove",  " KitchenAid stainless steel oven" : "Oven",
 " Kitchenaid stainless steel oven" : "Oven",  " Kitchenette" : "Kitchen", " Lake access" : "Lake access",
" Laptop-friendly workspace": "Workspace",   " Laundromat nearby" : "Laundromat nearby",
" LG gas stove" : "Stove",  " LG oven" : "Oven", " LG refrigerator" : "Refrigerator",
" Limited housekeeping \\u2014 " : "Housekeeping",  " liquid body soap" : "Shower gel",
" Little Seed Farm sustainable handcrafted bar soap (zero waste!) body soap" : "Soap",
" Lock on bedroom door": "Bedroom lock",  " Lockbox": "Lockbox",
" Long term stays allowed": "Extended stay", " Loreal conditioner" : "Conditioner",
" Love" : "Other", " Luggage dropoff allowed": "Luggage dropoff allowed", 
" Microwave":"Microwave",   " Mini fridge" : "Refrigerator",  " Natural / Vegan body soap" :  "Soap",
" Natural / Vegan conditioner" : "Conditioner", " Natural / Vegan shampoo" : "Shampoo",
 " Natural Spa Quality" : "Other", " Nespresso machine" : "Coffee machine",
" New.  It  four burners very good full size stove and full oven. It is white. electric stove" : "Stove",
" No stove but has a hot plate electric stove" : "Hot plate", " Nourishes and Cleans Skin" : "Soap",
" Nutresse shampoo and conditioner conditioner" : "Shampoo",
" Onsite restaurant \\u2014 Cosmica" : "Other",  " Outdoor Grill gas stove" : "Stove",
 " Outlet covers" : "Other",   " Oven" : "Oven", " Pack \\u2019n Play/travel crib" : "Travel crib",
 " Paid parking garage off premises" : "Paid parking off premise",
       " Paid parking garage on premises \\u2013 1 space" : "Paid parking on premise",
 " Paid parking garage on premises" : "Paid parking on premise",
       " Paid parking lot off premises" : "Paid parking off premise",
       " Paid parking lot on premises \\u2013 1 space" : "Paid parking on premise",
       " Paid parking lot on premises"  : "Paid parking on premise",
       " Paid parking off premises" : "Paid parking off premise", 
       " Paid parking on premises \\u2013 1 space" : "Paid parking on premie",
" Paid parking on premises" : "Paid parking on premise",
 " Paid street parking off premises" : "Paid parking off premise",
       " Panasonic sound system" : "Sound system", " Pantene conditioner" : "Conditioner",
 " Pantene shampoo" : "Shampoo",  " Paraben" : "Other",  " Patio or balcony": "Patio or balcony",
" Pets allowed" : "Pets allowed",  " Phosphate" : "Other", " Piano" : "Piano",
" Pocket wifi" : "Wifi",
" Polk sound bar can be accessed via your wifi/phone sound system" : "Sound system",
 " Pool" : "Pool",  " High chair" : "High chair",  " Portable air conditioning" : "Portable air conditioning",
       " Portable fans" : "Portable fans",  " Portable heater" : "Portable heater",
" Pour Over Coffee" : "Coffee",  " premium cable" : "TV with Cable",  " Private entrance" : "Private entrance",
" Private hot tub" : "Hot tub",   " Private living room" : "Private space",  " Radiant heating" : "Heating",
" Record player" : "Other",  " Refrigerator" : "Refrigerator",  " Rice Maker" : "Other", 
" Room-darkening shades" : "Room darkening shades",  " Safe" : "Safe",  " Samsung oven" : "Oven",
 " Samsung refrigerator" : "Refrigerator",
" Samsung Soundbar M5 sound system with Bluetooth and aux" : "Bluetooth sound system",
" Samsung stainless steel electric stove" : "Stove", " Samsung stainless steel gas stove" : "Stove",
 " Samsung stainless steel oven" : "Oven",   " Selection of travel size provided conditioner" : "Conditioner",
 " Self check-in" : "Self check in",  " Self-parking \\u2014 $42/stay" : " Paid on premise parking",
 " Shampoo" : "Shampoo",   " Shared hot tub" : "Hot tub", " Shower gel" : "Body wash", 
" Single level home" : "Other",  " Ski-in/Ski-out" : "Ski-in and ski-out" ,   " Slippers" : "Other",
" Smart Inverter refrigerator" : "Refrigerator", " Smart lock" : "Smart lock",  "Bathtub" : "Bathtub",
" Smoking allowed" : "Smoking allowed", " Softens" : "Other", "Bed sheets and pillows" : "Bed sheets and pillows",
 " Sonos Bluetooth sound system" : "Bluetooth sound system", 
 " Sonos sound system" : "Bluetooth sound system", 
 " Sound system with aux" : "Sound system with aux",  " Sound system" : "Sound system", 
" Stainless fridge/freezer refrigerator" : "Refrigerator", " Stainless steel electric stove" : "Stove",
" Stainless steel gas stove" : "Stove",  " Stainless steel induction stove" : "Stove",
" Stainless steel oven" : "Oven", " Stainless steel stove" : "Stove",  " Stair gates" : "Other",
" standard cable" : "TV with cable", " Stove": "Stove", " Sub Zero refrigerator" : "Refrigerator",
" Sub zero refrigerator" : "Refrigerator", " Suitable for events" : "Other",  " Sulfate" : "Other",
" Summit refrigerator" : "Refrigerator",  " Table corner guards" : "Other",  " thermostat": "Oher",
 " Toiletries" : "Essentials", " Trash compactor" : "Other",   " TV with Chromecast" : "TV with Chromecast", 
" TV with Netflix" : "TV with Netflix" ,   " TV": "TV", 
  " Usually Palmolive bar soap and Soft Soap pump in addition to shower gel. body soap" : "Body wash",
" Varies body soap" : "Body wash", " Varies conditioner": "Conditioner",  " variety body soap" : "Body wash",
 " variety conditioner" : "Conditioner",   " vegan and cruelty-free body soap" : "Body wash",
" vegan and cruelty-free conditioner" : "Conditioner",  " vegan and cruelty-free shampoo" : "Shampoo",
" Viking stainless steel gas stove" : "Stove", " viking stainless steel oven" : "Oven",
 " Washer \\u2013\\u00a0In building" : "Washer",  " Washer \\u2013\\u00a0In unit" : "Washer",
" Washer": "Washer", " Waterfront" : "Waterfront",  " Whole Foods Grapefruit body soap" : "Body wash",
" Whole Foods Grapefruit conditioner" : "Conditioner", " Wifi" : "Wifi" ,  " Wifi \\u2013 100 Mbps" : "Wifi",
 " Wifi \\u2013 15 Mbps" : "Wifi",  " HDTV with premium cable" : "TV with Cable",
 " Wifi \\u2013 150 Mbps" : "Wifi",  " Wifi \\u2013 200 Mbps" : "Wifi", " Wifi \\u2013 363 Mbps" : "Wifi",
 " Game room" : "Game room",  " Wifi \\u2013 60 Mbps" : "Wifi", " Wifi \\u2013 600 Mbps" : "Wifi",
" Wifi \\u2013 70 Mbps" : "Wifi", " Wifi \\u2013 90 Mbps" : "Wifi", " Wifi \\u2013 940 Mbps" : "Wifi",
 " Wifi \\u2013 980 Mbps" : "Wifi", " Window AC unit" : "Window Air Conditioner",
 " Window guards" : "Other", " Dr Bonner's  shampoo" : "Shampoo",
" If Dominic goes shopping it's likely a name brand like Ivory" : "Soap",
" if I go shopping it's a bit more bougie. Enjoy the element of surprise while staying at our home! body soap":"Body wash",
" I'm not sure of brand" : "Other",
 " L'occitane bar soap" : "Other", " Trader Joe's Tea Tree shampoo" : "Shampoo",
" Trader Joe's Tea Tree shower gel and selection of bar soaps body soap" : " Body wash",
 " Fire extinguisher": "Fire extinguisher",  " Laundry services" : "Laundry",
"40\\ HDTV with Netflix" : "TV with Netflix",  "Air conditioning" : "Air conditioning",
"Alba or Pantene conditioner" : "Conditioner", "Smoke alarm": "Smoke Alarm", "Baby bath" : "Bassinette",
 "Barbecue utensils" : "Kitchenware", "Bath & Body Works shampoo" : "Shampoo",
 "Bed linens" : "Bed linens", "Bedroom comforts" : "Bed linens and pillows",
"BOSCH stainless steel gas stove" : "Stove",  "Breakfast" : "Breakfast", "Building staff" : "Staff on site",
 "Carbon monoxide alarm" : "Carbon monoxide alarm",
"Children\\u2019s books and toys" : "Childrens books and toys",
 "Children\\u2019s dinnerware" : "Childrens dinnerware",  "Conditioner" : "Conditioner",
 "Cooking basics" : "Kitchenware", "Dacor duel fuel - gas stove top" : "Stove",  "Dishwasher" : "Dishwasher",
"Elevator" : "Elevator",  "Essentials" : "Essentials",  "Fire extinguisher" : "Fire extinguisher",
"Free street parking" : "Free off premise parking",
"Ginger Lily Farms Club & Fitness Aloe Vera Moisturizing Conditioner" : "Conditioner",
 "Hair dryer" : "Hair dryer",  "Hangers" : "Hangers", "Hot water" : "Hot water",   "Keypad" : "Smart keypad",
 "Kitchen" : "Kitchen",    "Kitchenaid stainless steel oven" : "Oven", "Lake access" : "Lake access",
"Laptop-friendly workspace" : "Workspace",   "Laundromat nearby" : "Laundromat nearby",
 "Lock on bedroom door" : "Lock on bedroom door", "Long term stays allowed" : "Long term stay allowed",
"Luggage dropoff allowed" : "Luggage dropoff allowed",  "Mini fridge" : "Refrigerator",
 "Nutresse shampoo shampoo" : "Shampoo", "Outlet covers" : "Child safety",
"Oven" : "Oven", "Paid parking garage off premises" : "Paid parking off premise",
 "Paid parking on premises" : "Paid parking on premise",  "Private entrance" : "Private entrance",
 "Smoke alarm" : "Smoke alarm", "Stainless steel oven" : "Oven",  "TV" : "TV",  "Washer" : "Washer",
"Wifi \\u2013 60 Mbps" : "Wifi"}

# %%
for i, j in amenities_list:
    for amenity in amenities:
   air_listings['amenities1'] = np.where(air_listings.amenities == i, j, air_listings.amenities)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-338-022c4dc7018e> in <module>
# ----> 1 for i, j in amenities_list:
#       2    air_listings['amenities1'] = np.where(air_listings.amenities == i, j, air_listings.amenities)
#
# ValueError: too many values to unpack (expected 2)

# %%
air_listings['property_type'] = np.where(air_listings.property_type.isnull(), 'Not identified',\
                                              air_listings.property_type) [1]:
    for amenity in amenities:
        air_listings['amenities1'] = air_listings['amenities'].map(amenities_list)

#air_listings['amenities_mapping'] = [amenities_list[x] for x in air_listings['amenities']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-337-2510c54c5aa9> in <module>
#       1 #df['Capital'] = df['Country'].map(country_capital)
#       2
# ----> 3 for i in amenities_list[1]:
#       4     for amenity in amenities:
#       5         air_listings['amenities1'] = air_listings['amenities'].map(amenities_list)
#
# KeyError: 1

# %%
air_listings[['amenities1', 'amenities']].sample(30)
# Out:
#      amenities1            amenities
# 2838        NaN  ["Iron", "TV", "...
# 2725        NaN  ["Hot water", "W...
# 2040        NaN  ["Washer", "Kitc...
# 361         NaN  ["Lockbox", "Kit...
# 3571        NaN  ["Iron", "TV", "...
# ...         ...                  ...
# 2371        NaN  ["Iron", "Hanger...
# 2019        NaN  ["Iron", "TV", "...
# 290         NaN  ["Wifi", "Washer...
# 1135        NaN  ["Luggage dropof...
# 1221        NaN  ["Iron", "TV", "...
#
# [30 rows x 2 columns]

# %%
PrimList = {}

if appt_ in PrimList:
    print(PrimList[appt_])

# %%
air_listings['amenities_mapped'] = amenities_list( (key, value) for (key, value) in air_listings.amenities.items() if key ==  )

# %%
    
# change to "not provided"
air_listings['amenities'] = np.where((air_listings.amenities== amenities_list[0]), amenities_list.value, 
                                               air_listings.amenities_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-311-c9608a5b1d86> in <module>
#       1 # change to "not provided"
# ----> 2 air_listings['amenities'] = np.where((air_listings.amenities== amenities_list.key), amenities_list.value,
#       3                                                air_listings.amenities_list)
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
air_listings.amenities_mapped.sample(20)
# Out:
# 849     NaN
# 2903    NaN
# 1269    NaN
# 3278    NaN
# 659     NaN
# 29      NaN
# 521     NaN
# 557     NaN
# 3921    NaN
# 2983    NaN
# 89      NaN
# 2293    NaN
# 3173    NaN
# 2078    NaN
# 3606    NaN
# 3837    NaN
# 1932    NaN
# 2304    NaN
# 1781    NaN
# 1710    NaN
# Name: amenities_mapped, dtype: object

# %%
air_listings[collist] = boolean_df(air_listings['amenities'], unique_items.keys())
air_listings
# Out:
#             id          listing_url       scrape_id last_scraped  \
# 0         2318  https://www.airb...  20201025051148   2020-10-25
# 1         9419  https://www.airb...  20201025051148   2020-10-25
# 2         9531  https://www.airb...  20201025051148   2020-10-25
# 3         9534  https://www.airb...  20201025051148   2020-10-25
# 4         9596  https://www.airb...  20201025051148   2020-10-25
# ...        ...                  ...             ...          ...
# 3231  46262706  https://www.airb...  20201110041432   2020-11-10
# 3232  46263409  https://www.airb...  20201110041432   2020-11-10
# 3233  46292830  https://www.airb...  20201110041432   2020-11-10
# 3234  46326856  https://www.airb...  20201110041432   2020-11-10
# 3235  46330627  https://www.airb...  20201110041432   2020-11-10
#
#                      name          description neighborhood_overview  \
# 0     Casa Madrona - U...  Gorgeous, archit...  Madrona is a hid...
# 1     Glorious sun roo...  Keeping you safe...  Lots of restaura...
# 2     The Adorable Swe...  The Sweet Orange...  The neighborhood...
# 3     The Coolest Tang...  Welcome to my de...  The neighborhood...
# 4     the down home , ...  We are in a grea...  if you arrive ea...
# ...                   ...                  ...                  ...
# 3231  Luxury Boston Ap...  Stay at the best...         Not provided
# 3232  Stay in a place ...  Stay for 92+ nig...         Not provided
# 3233  Beautiful Bedroo...  Located in the b...  The apartment is...
# 3234  Luxury 2 Bed in ...  In the heart of ...  Boston, the capi...
# 3235  33 Highland 1D |...  If you are looki...         Not provided
#
#               picture_url    host_id             host_url  host_name  \
# 0     https://a0.musca...       2536  https://www.airb...      Megan
# 1     https://a0.musca...      30559  https://www.airb...  Angielena
# 2     https://a0.musca...      31481  https://www.airb...     Cassie
# 3     https://a0.musca...      31481  https://www.airb...     Cassie
# 4     https://a0.musca...      14942  https://www.airb...      Joyce
# ...                   ...        ...                  ...        ...
# 3231  https://a0.musca...  158837906  https://www.airb...     Hesham
# 3232  https://a0.musca...  359229620  https://www.airb...        Kia
# 3233  https://a0.musca...   69252401  https://www.airb...      Adler
# 3234  https://a0.musca...   22541573  https://www.airb...        Ken
# 3235  https://a0.musca...     814298  https://www.airb...     Thatch
#
#                host_since        host_location           host_about  \
# 0     1219708800000000000  Seattle, Washing...  I welcome guests...
# 1     1249776000000000000  Seattle, Washing...  I am a visual ar...
# 2     1250121600000000000  Seattle, Washing...  The Sweet Orange...
# 3     1250121600000000000  Seattle, Washing...  The Sweet Orange...
# 4     1240704000000000000  Seattle, Washing...  I am a therapist...
# ...                   ...                  ...                  ...
# 3231  1510704000000000000  Watertown, Massa...         Not provided
# 3232  1595980800000000000  Houston, Texas, ...         Not provided
# 3233  1461715200000000000  Boston, Massachu...  Hello fellow Air...
# 3234  1413244800000000000  New York, New Yo...  I work for Furni...
# 3235  1310515200000000000  Boston, Massachu...  Thatch is the pr...
#
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 0           within a day               100.0                 78.0
# 1     within a few hours               100.0                 89.0
# 2           within a day               100.0                 64.0
# 3           within a day               100.0                 64.0
# 4     within a few hours                90.0                 94.0
# ...                  ...                 ...                  ...
# 3231      within an hour                97.0                 98.0
# 3232  within a few hours                95.0                 86.0
# 3233      within an hour               100.0                100.0
# 3234      within an hour                99.0                 89.0
# 3235  within a few hours                94.0                 98.0
#
#      host_is_superhost   host_thumbnail_url     host_picture_url  \
# 0                 True  https://a0.musca...  https://a0.musca...
# 1                 True  https://a0.musca...  https://a0.musca...
# 2                 True  https://a0.musca...  https://a0.musca...
# 3                 True  https://a0.musca...  https://a0.musca...
# 4                False  https://a0.musca...  https://a0.musca...
# ...                ...                  ...                  ...
# 3231             False  https://a0.musca...  https://a0.musca...
# 3232              True  https://a0.musca...  https://a0.musca...
# 3233             False  https://a0.musca...  https://a0.musca...
# 3234             False  https://a0.musca...  https://a0.musca...
# 3235             False  https://a0.musca...  https://a0.musca...
#
#        host_neighbourhood host_listings_count  host_total_listings_count  \
# 0                   Minor                 2.0                  2.0
# 1              Georgetown                 8.0                  8.0
# 2            The Junction                 2.0                  2.0
# 3            The Junction                 2.0                  2.0
# 4             Wallingford                 5.0                  5.0
# ...                   ...                 ...                  ...
# 3231        Jamaica Plain                 8.0                  8.0
# 3232  Springfield/Belmont              1515.0               1515.0
# 3233              Roxbury                 0.0                  0.0
# 3234      Upper East Side               113.0                113.0
# 3235              Roxbury               102.0                102.0
#
#        host_verifications host_has_profile_pic host_identity_verified  \
# 0     ['email', 'phone...                 True                 True
# 1     ['email', 'phone...                 True                 True
# 2     ['email', 'phone...                 True                 True
# 3     ['email', 'phone...                 True                 True
# 4     ['email', 'phone...                 True                 True
# ...                   ...                  ...                  ...
# 3231  ['email', 'phone...                 True                 True
# 3232   ['email', 'phone']                 True                 True
# 3233  ['email', 'phone...                 True                 True
# 3234  ['email', 'phone...                 True                 True
# 3235  ['email', 'phone...                 True                 True
#
#             neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed  \
# 0     Seattle, Washing...              Madrona           Central Area
# 1     Seattle, Washing...           Georgetown    Other neighborhoods
# 2     Seattle, Washing...       Fairmount Park           West Seattle
# 3     Seattle, Washing...       Fairmount Park           West Seattle
# 4     Seattle, Washing...          Wallingford    Other neighborhoods
# ...                   ...                  ...                    ...
# 3231       Not identified        Jamaica Plain                missing
# 3232       Not identified           Dorchester                missing
# 3233  Boston, Massachu...              Roxbury                missing
# 3234  Boston, Massachu...               Fenway                missing
# 3235       Not identified              Roxbury                missing
#
#        latitude   longitude        property_type        room_type  \
# 0     47.610820 -122.290820         Entire house  Entire home/apt
# 1     47.550170 -122.319370  Private room in ...     Private room
# 2     47.555390 -122.384740         Entire house  Entire home/apt
# 3     47.556240 -122.385980   Entire guest suite  Entire home/apt
# 4     47.654790 -122.336520     Entire apartment  Entire home/apt
# ...         ...         ...                  ...              ...
# 3231  42.328050  -71.111290     Entire apartment  Entire home/apt
# 3232  42.283450  -71.036350  Entire serviced ...  Entire home/apt
# 3233  42.326560  -71.093690     Entire apartment  Entire home/apt
# 3234  42.343049  -71.085786     Entire apartment  Entire home/apt
# 3235  42.329770  -71.092140  Private room in ...     Private room
#
#       accommodates  bathrooms  bedrooms      beds            amenities  price  \
# 0                9        2.5       4.0  4.000000  ["Children\u2019...  295.0
# 1                2        3.0       1.0  2.000000  ["Iron", "Hanger...   55.0
# 2                4        1.0       2.0  3.000000  ["Iron", "TV", "...  155.0
# 3                3        1.0       2.0  2.000000  ["Conditioner", ...  125.0
# 4                4        1.0       1.0  4.000000  ["Iron", "TV", "...  100.0
# ...            ...        ...       ...       ...                  ...    ...
# 3231             4        2.0       2.0  3.000000  ["Wifi", "Washer...  336.0
# 3232             3        1.0       1.0  1.000000  ["Washer", "Kitc...  137.0
# 3233             1        1.0       1.0  1.000000  ["Wifi", "Air co...   35.0
# 3234             5        2.0       2.0  2.000000  ["Washer", "Kitc...  170.0
# 3235             1        1.5       1.0  1.777068  ["Wifi", "Washer...   49.0
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0                  1              26                  1.0
# 1                  2             180                  2.0
# 2                 28             294                 28.0
# 3                  5             315                  5.0
# 4                  4              60                  4.0
# ...              ...             ...                  ...
# 3231               1             365                  1.0
# 3232              92             365                 92.0
# 3233               1               3                  1.0
# 3234              32             180                 32.0
# 3235              31             160                 31.0
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                     2.0                  1125.0                    26.0
# 1                     2.0                   180.0                   180.0
# 2                    28.0                  1125.0                   294.0
# 3                     5.0                  1125.0                   315.0
# 4                     4.0                  1125.0                     6.0
# ...                   ...                     ...                     ...
# 3231                  1.0                  1125.0                   365.0
# 3232                 92.0                   365.0                   365.0
# 3233                  1.0                  1125.0                    14.0
# 3234                 32.0                   180.0                   180.0
# 3235                 31.0                  1125.0                   160.0
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     1.0                    26.0                  NaN
# 1                     2.0                   180.0                  NaN
# 2                    28.0                   294.0                  NaN
# 3                     5.0                   315.0                  NaN
# 4                     4.0                     6.0                  NaN
# ...                   ...                     ...                  ...
# 3231                  1.0                   365.0                  NaN
# 3232                 92.0                   365.0                  NaN
# 3233                  1.0                    14.0                  NaN
# 3234                 32.0                   180.0                  NaN
# 3235                 31.0                   160.0                  NaN
#
#       has_availability  availability_30  ...  \
# 0                 True                0  ...
# 1                 True               29  ...
# 2                 True                0  ...
# 3                 True               10  ...
# 4                 True                0  ...
# ...                ...              ...  ...
# 3231              True               30  ...
# 3232              True                0  ...
# 3233              True                4  ...
# 3234              True                0  ...
# 3235              True               10  ...
#
#        Whole Foods Grapefruit conditioner   Kitchenaid refrigerator  \
# 0                   False                                False
# 1                   False                                False
# 2                   False                                False
# 3                   False                                False
# 4                   False                                False
# ...                   ...                                  ...
# 3231                False                                False
# 3232                False                                False
# 3233                False                                False
# 3234                False                                False
# 3235                False                                False
#
#        Wifi \u2013 15 Mbps  HDTV with premium cable  \
# 0                   False                 False
# 1                   False                 False
# 2                   False                 False
# 3                   False                 False
# 4                   False                 False
# ...                   ...                   ...
# 3231                False                 False
# 3232                False                 False
# 3233                False                 False
# 3234                False                 False
# 3235                False                 False
#
#        Kitchenaid stainless steel oven   Frigidaire refrigerator  \
# 0                   False                             False
# 1                   False                             False
# 2                   False                             False
# 3                   False                             False
# 4                   False                             False
# ...                   ...                               ...
# 3231                False                             False
# 3232                False                             False
# 3233                False                             False
# 3234                False                             False
# 3235                False                             False
#
#        Summit refrigerator  Wifi \u2013 70 Mbps  Dove or Pantene conditioner  \
# 0                   False                 False                False
# 1                   False                 False                False
# 2                   False                 False                False
# 3                   False                 False                False
# 4                   False                 False                False
# ...                   ...                   ...                  ...
# 3231                False                 False                False
# 3232                False                 False                False
# 3233                False                 False                False
# 3234                False                 False                False
# 3235                False                 False                False
#
#        if I go shopping it's a bit more bougie. Enjoy the element of surprise while staying at our home! body soap  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        if needed refrigerator   liquid body soap   Dr. Teals body soap  \
# 0                   False                  False                False
# 1                   False                  False                False
# 2                   False                  False                False
# 3                   False                  False                False
# 4                   False                  False                False
# ...                   ...                    ...                  ...
# 3231                False                  False                False
# 3232                False                  False                False
# 3233                False                  False                False
# 3234                False                  False                False
# 3235                False                  False                False
#
#        Dr. Bronners body soap   Dr Bonner's  shampoo  \
# 0                   False                    False
# 1                   False                    False
# 2                   False                    False
# 3                   False                    False
# 4                   False                    False
# ...                   ...                      ...
# 3231                False                    False
# 3232                False                    False
# 3233                False                    False
# 3234                False                    False
# 3235                False                    False
#
#        Stainless steel induction stove   Dove or Pantene shampoo  \
# 0                   False                             False
# 1                   False                             False
# 2                   False                             False
# 3                   False                             False
# 4                   False                             False
# ...                   ...                               ...
# 3231                False                             False
# 3232                False                             False
# 3233                False                             False
# 3234                False                             False
# 3235                False                             False
#
#        Dove conditioner   Wifi \u2013 90 Mbps   Natural Spa Quality  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
# ...                 ...                  ...                   ...
# 3231              False                False                 False
# 3232              False                False                 False
# 3233              False                False                 False
# 3234              False                False                 False
# 3235              False                False                 False
#
#        Stainless fridge/freezer refrigerator  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        New.  It  four burners very good full size stove and full oven. It is white. electric stove  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#       Danby refrigerator   Dacor duel fuel stove - electric oven   thermostat  \
# 0                  False                False                           False
# 1                  False                False                           False
# 2                  False                False                           False
# 3                  False                False                           False
# 4                  False                False                           False
# ...                  ...                  ...                             ...
# 3231               False                False                           False
# 3232               False                False                           False
# 3233               False                False                           False
# 3234               False                False                           False
# 3235               False                False                           False
#
#        variety body soap   KitchenAid refrigerator   gas stove top oven  \
# 0                  False                False                     False
# 1                  False                False                     False
# 2                  False                False                     False
# 3                  False                False                     False
# 4                  False                False                     False
# ...                  ...                  ...                       ...
# 3231               False                False                     False
# 3232               False                False                     False
# 3233               False                False                     False
# 3234               False                False                     False
# 3235               False                False                     False
#
#        Eco body soap   etc.) refrigerator   Electrolux refrigerator  \
# 0              False                False                False
# 1              False                False                False
# 2              False                False                False
# 3              False                False                False
# 4              False                False                False
# ...              ...                  ...                  ...
# 3231           False                False                False
# 3232           False                False                False
# 3233           False                False                False
# 3234           False                False                False
# 3235           False                False                False
#
#        Laundry services   Limited housekeeping \u2014   \
# 0                 False                False
# 1                 False                False
# 2                 False                False
# 3                 False                False
# 4                 False                False
# ...                 ...                  ...
# 3231              False                False
# 3232              False                False
# 3233              False                False
# 3234              False                False
# 3235              False                False
#
#        Little Seed Farm sustainable handcrafted bar soap (zero waste!) body soap  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        Sub zero refrigerator   Wifi \u2013 980 Mbps   Loreal conditioner  \
# 0                   False                   False                  False
# 1                   False                   False                  False
# 2                   False                   False                  False
# 3                   False                   False                  False
# 4                   False                   False                  False
# ...                   ...                     ...                    ...
# 3231                False                   False                  False
# 3232                False                   False                  False
# 3233                False                   False                  False
# 3234                False                   False                  False
# 3235                False                   False                  False
#
#        Free carport on premises   Fisher and Paykel stainless steel oven  \
# 0                   False                      False
# 1                   False                      False
# 2                   False                      False
# 3                   False                      False
# 4                   False                      False
# ...                   ...                        ...
# 3231                False                      False
# 3232                False                      False
# 3233                False                      False
# 3234                False                      False
# 3235                False                      False
#
#        Fisher and Paykel stainless steel gas stove  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        Fisher Paykel stainless steel gas stove  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        and Jayson body wash body soap  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        and because it is in the Studio I bought a self defrost because this keeps the room much quieter!  It has the freezer in the refrigerator. refrigerator  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        body wash body soap  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        but I bought new some years ago. It is older but has always worked very good  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        clock radio sound system with Bluetooth and aux  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 3231                False
# 3232                False
# 3233                False
# 3234                False
# 3235                False
#
#        double ovens stainless steel oven   electric oven gas stove  \
# 0                   False                               False
# 1                   False                               False
# 2                   False                               False
# 3                   False                               False
# 4                   False                               False
# ...                   ...                                 ...
# 3231                False                               False
# 3232                False                               False
# 3233                False                               False
# 3234                False                               False
# 3235                False                               False
#
#       Wifi \u2013 60 Mbps  amenities_mapped
# 0                   False               NaN
# 1                   False               NaN
# 2                   False               NaN
# 3                   False               NaN
# 4                   False               NaN
# ...                   ...               ...
# 3231                False               NaN
# 3232                False               NaN
# 3233                False               NaN
# 3234                False               NaN
# 3235                False               NaN
#
# [7571 rows x 467 columns]

# %%
collist1 = ['Wireless Internet', 'Heating', 'Kitchen', 'Essentials',
       'Smoke Detector', 'Dryer', 'Washer', 'Internet', 'TV', 'Shampoo',
       'Carbon Monoxide Detector', 'Family/Kid Friendly',
       'Fire Extinguisher', 'Air Conditioning', 'Cable TV',
       'Free Parking on Premises', 'Hangers', 'First Aid Kit',
       'Hair Dryer', 'Laptop Friendly Workspace', 'Iron',
       '24-Hour Check-in', 'Elevator in Building',
       'Buzzer/Wireless Intercom', 'Pets live on this property',
       'Indoor Fireplace', 'Safety Card', 'Unknown amenity',
       'Pets Allowed', 'Gym', 'Dog(s)', 'Breakfast',
       'Lock on Bedroom Door', 'Cat(s)', 'Hot Tub',
       'Wheelchair Accessible', 'Doorman', 'Suitable for Events', 'Pool',
       'Smoking Allowed', '', 'Other pet(s)', 'Free Parking on Street',
       'Paid Parking Off Premises', 'Washer / Dryer']

for cola in collist1:
    
    # Replace True/False with 1/0
    listings[cola].replace(True, 1, inplace=True)
    listings[cola].replace(False, 0, inplace=True)
# Replace NaN with 0
    listings[cola].replace('NaN', 0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Wireless Internet'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-486848332136> in <module>
#      17
#      18     # Replace True/False with 1/0
# ---> 19     listings[cola].replace(True, 1, inplace=True)
#      20     listings[cola].replace(False, 0, inplace=True)
#      21 # Replace NaN with 0
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Wireless Internet'

# %%
listings[['amenities', 'Wireless Internet', 'Heating', 'Kitchen', 'Essentials',
       'Smoke Detector', 'Dryer', 'Washer', 'Internet', 'TV', 'Shampoo',
       'Carbon Monoxide Detector', 'Family/Kid Friendly',
       'Fire Extinguisher', 'Air Conditioning', 'Cable TV',
       'Free Parking on Premises', 'Hangers', 'First Aid Kit',
       'Hair Dryer', 'Laptop Friendly Workspace', 'Iron',
       '24-Hour Check-in', 'Elevator in Building',
       'Buzzer/Wireless Intercom', 'Pets live on this property',
       'Indoor Fireplace', 'Safety Card', 'Unknown amenity',
       'Pets Allowed', 'Gym', 'Dog(s)', 'Breakfast',
       'Lock on Bedroom Door', 'Cat(s)', 'Hot Tub',
       'Wheelchair Accessible', 'Doorman', 'Suitable for Events', 'Pool',
       'Smoking Allowed', '', 'Other pet(s)', 'Free Parking on Street',
       'Paid Parking Off Premises', 'Washer / Dryer']].head()

# %%
#Get host_verifications

host_verify=get_column_name_list(air_listings.host_verifications, 'host_verifications') #Total



host_verify

host_verify/host_verify.sum()*100 #Percentage of total tags

(host_verify[0:35]/host_verify.sum()*100).sum()

host_verify

# %%
unique_items = host_verify

# %%
dummymatrix = boolean_df(air_listings['host_verifications'], unique_items.keys())
collist = dummymatrix.columns.values
collist

# %%
collist2 = ['email','phone', 'reviews', 'kba','jumio',
       'facebook', 'linkedin', 'google', 'manual_offline',
       'phone', 'amex', 'manual_online', 'weibo', 'sent_id',
       'photographer', 'None', '','reviews','facebook',
       'google']

# %%
air_listings[collist2] = boolean_df(air_listings['host_verifications'], unique_items.keys())
air_listings

# %%
collist2 = ['email','phone', 'reviews', 'kba','jumio',
       'facebook', 'linkedin', 'google', 'manual_offline',
       'phone', 'amex', 'manual_online', 'weibo', 'sent_id',
       'photographer', 'None', '','reviews','facebook',
       'google']

for cola in collist2:
    
    # Replace True/False with 1/0
    air_listings[cola].replace(True, 1, inplace=True)
    air_listings[cola].replace(False, 0, inplace=True)
# Replace NaN with 0
    air_listings[cola].replace('NaN', 0, inplace=True)

# %%
air_listings[['host_verifications','email','phone', 'reviews', 'kba','jumio',
       'facebook', 'linkedin', 'google', 'manual_offline',
       'phone', 'amex', 'manual_online', 'weibo', 'sent_id',
       'photographer', 'None', '','facebook',
       'google']].head()

# %%
air_listings.host_is_superhost.head()

# %% [markdown]
# ### Question - What proportion of hosts are Superhosts?

# %%
prop_superhosts = air_listings.groupby(listings['host_is_superhost'])['host_is_superhost'].count()
prop_superhosts

plot = prop_superhosts.plot.pie(y='host_is_superhost', figsize=(5, 5))

# %% [markdown]
# ### Modeling

# %%
nulls={}
for feat in keep:
    nulls[feat]=air_listings2[feat].isnull().sum()*1.0/len(air_listings2[feat])
nulls

# %% [markdown]
# ### Modeling

# %%
y=air_listings2.review_scores_rating

# %%
full_list = collist1 + collist2
X = air_listings2[full_list]

# %%
# save air_listings, air_calendar and air_ratings files to .csv file
air_listings.to_csv('air_listins.csv', index = False, encoding = 'utf-8')
air_calendar.to_csv('air_calendar.csv', index = False, encoding = 'utf-8')
air_reviews.to_csv('air_reviews.csv', index = False, encoding = 'utf-8')
