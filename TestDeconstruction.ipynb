# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
from matplotlib import style
style.use('ggplot')

# %%
# Change default settings to allow seeing all of the data in a table.
pd.options.display.max_columns = 100
pd.options.display.max_rows = 20
pd.set_option('display.max_colwidth', 20)

# Supress warnings
warnings.filterwarnings("ignore")

# %%
'''This code reads the comma separated data downloade from the AirBnB website

    The data was provided by Udacity in support of the Data Science Nanodegree.'''

# Read in Seattle Data
airbnb_seattle_calendar = pd.read_csv('calendar-Seattle.csv')
airbnb_seattle_listings = pd.read_csv('listings-Seattle.csv')
airbnb_seattle_reviews = pd.read_csv('reviews-Seattle.csv')

# Read in Boston Data
airbnb_boston_calendar = pd.read_csv('calendar-Boston.csv')
airbnb_boston_listings = pd.read_csv('listings-Boston.csv')
airbnb_boston_reviews = pd.read_csv('reviews-Boston.csv')

# %%
# Create identifiers for each file before joining cities
airbnb_seattle_calendar['city'] = 'Seattle'
airbnb_seattle_listings['city'] = 'Seattle'
airbnb_seattle_reviews['city'] = 'Seattle'
airbnb_boston_calendar['city'] = 'Boston'
airbnb_boston_listings['city'] = 'Boston'
airbnb_boston_reviews['city'] = 'Boston'

# %%
# Check shape of files
print(airbnb_seattle_calendar.shape, airbnb_boston_calendar.shape)
print(airbnb_seattle_listings.shape, airbnb_boston_listings.shape)
print(airbnb_seattle_reviews.shape, airbnb_boston_reviews.shape)
# Out:
# (1393570, 5) (1308890, 5)
# (3818, 92) (3585, 95)
# (84849, 7) (68275, 7)

# %%
# Join the files
frames_calendar = [airbnb_seattle_calendar,airbnb_boston_calendar ]
frames_listings = [airbnb_seattle_listings, airbnb_boston_listings]
reviews_listings =[airbnb_seattle_reviews, airbnb_boston_reviews]

calendar = pd.concat(frames_calendar)
listings = pd.concat(frames_listings)
reviews = pd.concat(reviews_listings)

# %%
# View the data in the file
listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                                                                                                                                                                                    summary  \
# ...

# %%
# View specific amenities
amenit= listings.amenities.value_counts()
print(amenit)
# Out:
# {}                                                                                                                                                                                                                                                                                                                  77
# {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,Heating,Washer,Dryer,"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}                                                                                                                                       15
# {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Fire Extinguisher","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}                                                                                                  14
# ...

# %%
# create a function to clean the list of strings
def clean_alt_list1(list_):
    list_ = list_.replace(',', '","')
    list_ = list_.replace('{', '["')
    list_ = list_.replace('}', '"]')
    list_ = list_.replace(',', '","')
    return list_

# %%
# cleans up double quotes
def clean_alt_list2(list_):
    list2_ = list_.replace('""', '"')
    return list2_

# %%
def clean_alt_list3(list_):
    list3_ = list_.replace('}', '"]')
    return list3_

# %%
# cleans up what is missed by previous items
def clean_alt_list4(list_):
    list4_ = list_.replace('["]', "NaN")
    return list4_

# %%
# use functions to clean amenities
listings['amenities'] = listings['amenities'].apply(clean_alt_list)


listings['amenities'] = listings['amenities'].apply(clean_alt_list2)
listings['amenities'] = listings['amenities'].apply(clean_alt_list3)
listings['amenities'] = listings['amenities'].apply(clean_alt_list4)
listings['amenities'] = listings['amenities'].apply(clean_alt_list2)


#listings['amenities'].apply(clean_alt_list2)
pd.set_option('display.max_colwidth', 200)
print(listings.amenities.head())
# Out:
# 0                                                                             ["TV","Cable TV","Internet","Wireless Internet","Air Conditioning","Kitchen","Heating","Family/Kid Friendly","Washer","Dryer"]
# 1    ["TV","Internet","Wireless Internet","Kitchen","Free Parking on Premises","Buzzer/Wireless Intercom","Heating","Family/Kid Friendly","Washer","Dryer","Smoke Detector","Carbon Monoxide Detector","F...
# 2    ["TV","Cable TV","Internet","Wireless Internet","Air Conditioning","Kitchen","Free Parking on Premises","Pets Allowed","Pets live on this property","Dog(s)","Cat(s)","Hot Tub","Indoor Fireplace","...
# 3    ["Internet","Wireless Internet","Kitchen","Indoor Fireplace","Heating","Family/Kid Friendly","Washer","Dryer","Smoke Detector","Carbon Monoxide Detector","Safety Card","Fire Extinguisher","Essenti...
# ...

# %%
def to_1D(series):
    return pd.Series([x for _list in series for x in _list])

to_1D(amen).value_counts()
# Out:
# "    223393
# e    165262
# r    115035
# i    106900
# ,    104332
#       ...
# G       921
# 5       581
# 0       581
# 9       444
# O        71
# Length: 59, dtype: int64

# %%
amenit = listings.amenities
